# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"
from IPython.display import Image

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.sandbox.stats.multicomp import MultiComparison

from scipy import stats
import scipy 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from pycaret.regression import *
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import pandas_profiling
import statsmodels.api as sm
from sklearn.decomposition import PCA
from statsmodels.miscmodels.ordinal_model import OrderedModel

# %% [markdown]
# ### 자료 소개
#
# **`grid_250_all.csv`는 전주시를 250x250 나눈 후 인구와 공간적 데이터, 그리고 범죄주의구간(폭행, 절도, 성폭행) 등급의 강도로 구성되어있다.
# 해당 데이터를 통해 전주시의 3대 범죄 발생에 영향을 끼치는 요인을 파악 후 범죄 위험지역에 대해 판단해 보려한다.**
#
# **데이터는 국가정보포털에서 격자별 인구 및 건축물에 대한 데이터를 수집하였으며, 가로등 주차장 등은 각 데이터의 좌표를 기준으로 격자내의 개수를 입력하였다.**
# **범죄주의구간은 생활안전지도의 치안사고발생현황을 바탕으로 만들어진 범죄주의구간 (1~10등급)의 지도를 이용하여 격자별 주의구간의 등급을 산정했다. (각 등급의 최대값)**
# 자료는 총 43개의 변수로 구성되어 있으며, 격자는 총 918개이다.
#
# #### raw data
# <code>gird_250</code> = 전주시 범죄관련 데이터
# - <code>INDEX</code> = 인덱스
# - <code>ID</code> = 각 격자의 고유 ID
# - <code>총인구</code> = 격자별 총인구
# - <code>고등여성인구</code> = 격자별 고등학생 여성인구(이 변수는 성폭력 취약인구에 포함)
# - <code>20대여성인구</code> = 격자별 20대 여성인구(이 변수는 성폭력 취약인구에 포함)
# - <code>유소년인구</code> = 격자별 유소년인구(0~14세)
# - <code>고령인구</code> = 격자별 고령인구(65세 이상)
# - <code>30년이상35년미만건축물</code> = 30년이상 35년미만건축물의 수
# - <code>35년이상건축물</code> = 35년이상 건축물
# - <code>개별주택가격</code> = 격자별 개별주택가격의 평균
# - <code>공시지가</code> = 격자별 평균 공시지가
# - <code>행정동코드</code> = 격자가 속한 행정동
# - <code>가로등</code> = 격자별 가로등의 수
# - <code>공영주차장</code> = 격자별 공영주차장수
# - <code>공중화장실</code> = 격자별 공중화장실수
# - <code>교육시설</code> = 격자별 교육시설의 수 (학원, 어린이집)
# - <code>대규모점포</code> = 격자별 대규모 점포의 수 (홈플러스, 이마트 등)
# - <code>대부업현황</code> = 격자별 대부업체의 수
# - <code>룸살롱</code> = 격자별 룸살롱의 수
# - <code>버스정류장</code> = 격자별 버스정류장의 수
# - <code>보안등</code> = 격자별 보안등의 수
# - <code>상가</code> = 격자별 상가의 수 (교육시설,음식점,술집,도소매업 오락시설을 포함한 상가의 수)
# - <code>숙박업소</code> = 격자별 숙박업소의 수
# - <code>술집</code> = 격자별 술집 (술집+룸살롱)
# - <code>어린이보호</code> = 격자별 어린이보호구역의 수
# - <code>어린이집</code> = 격자별 어린이집 수
# - <code>오락시설</code> = 격자별 오락시설 (노래방, 당구장, pc방 등)
# - <code>원룸_오피스텔</code> = 격자별 원룸 및 오피스텔의 수
# - <code>음식점</code> = 격자별 음식점 수
# - <code>자율방범대</code> = 격자별 자율방범대 수
# - <code>파출소</code> = 격자별 파출소의 수
# - <code>cctv</code> = 격자별 cctv 수
# - <code>신호등</code> = 격자별 신호등의 수
# - <code>횡단보도</code> = 격자별 횡단보도의 수
# - <code>GRADE_전체</code> = 격자별 범죄주의등급(2~11)

# %%
grid_250 = pd.read_csv('/Users/gimdong-wan/Desktop/DataCampus/data/real_data/250grid_all.csv')

# %%
grid_250 = grid_250.fillna(0)

# %% [markdown]
# #### 파생변수 생성 및 변수 조정
# - 고등여성인구 + 20대여성인구 = 성폭력취약인구
# - 건축물(30_34)+ 건축물(35) = 30년 이상 건축물
# - GRADE가 원래 1~10이나, 데이터 수집 과정에서 에러가 있어 2~11을 1로 조정
# - 필요없는 변수 제거

# %%
grid_250['성폭력취약인구'] = grid_250['고등여성인구']+grid_250['20대여성인구']
grid_250['건축물(30_)'] = grid_250['건축물(30_34)']+grid_250['건축물(35)']
grid_250['GRADE_전체'] = grid_250['GRADE_전체'].apply(lambda x: x-1 if x>0 else x)
grid_250 = grid_250.drop(columns = ['20대여성인구','고등여성인구','INDEX'])

# %% [markdown]
# ### 공시지가와, 종속변수 제외 모든 변수가 0인 행 탐색

# %%
feat_N = grid_250[(grid_250['총인구']==0)&(grid_250['건축물(30_34)']==0)&(grid_250['건축물(35)']==0)&(grid_250['가로등']==0)&(grid_250['공영주차장']==0)&(grid_250['공중화장실']==0)&(grid_250['숙박업소']==0)
        &(grid_250['대규모점포']==0)&(grid_250['대부업현황']==0)&(grid_250['상가']==0)&(grid_250['어린이보호']==0)&(grid_250['원룸_오피스텔']==0)&(grid_250['cctv']==0)&(grid_250['신호등']==0)&(grid_250['횡단보도']==0)
        &(grid_250['버스정류장']==0)&(grid_250['개별주택가격']==0)] #target 제외 모든 변수가 0인 row
feat_Y = grid_250[(grid_250['총인구']>0)|(grid_250['건축물(30_34)']>0)|(grid_250['건축물(35)']>0)|(grid_250['가로등']>0)|(grid_250['공영주차장']>0)|(grid_250['공중화장실']>0)|(grid_250['숙박업소']>0)
        |(grid_250['대규모점포']>0)|(grid_250['대부업현황']>0)|(grid_250['상가']>0)|(grid_250['어린이보호']>0)|(grid_250['원룸_오피스텔']>0)|(grid_250['cctv']>0)|(grid_250['신호등']>0)|(grid_250['횡단보도']>0)
        |(grid_250['버스정류장']>0)|(grid_250['개별주택가격']>0)] #target 제외 모든 변수가 0보다 큰 row

# %%
print(len(grid_250),len(feat_N),len(feat_Y))
# Out:
# 3498 1460 2038

# %% [markdown]
# - 모든 피쳐가 0인 행이 `1460`개이고, 한 피쳐라도 0보다 큰 행은 `2038`개

# %%
feat_N_ID = list(feat_N['ID'])
out = open('/Users/gimdong-wan/Desktop/out.txt','w')
print(feat_N_ID,file = out)

# %%
Image("/Users/gimdong-wan/Desktop/DataCampus/img/feat_N_grid/전체.png")

# %%
Image("/Users/gimdong-wan/Desktop/DataCampus/img/feat_N_grid/확대.png")

# %% [markdown]
# #### 해당 격자들은 대부분 산지나, 강, 도로 등 시설물이 없는 곳들을 나타낸다.
# #### 따라서 본 연구는 범죄에 영향을 미치는 요인을 파악하기 위함이므로 제거해도 좋을 것 이라 판단된다.

# %%
new_grid = feat_Y

# %%
new_grid.columns
# Out:
# Index(['ID', '총인구', '유소년인구', '고령인구', '건축물(30_34)', '건축물(35)', '개별주택가격', '공시지가',
#        '행정동코드', '가로등', '공영주차장', '공중화장실', '교육시설', '대규모점포', '대부업현황', '룸살롱',
#        '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집', '오락시설', '원룸_오피스텔',
#        '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도', 'GRADE_전체', '행정동면적',
#        '성폭력취약인구', '건축물(30_)'],
#       dtype='object')

# %%
new_grid.to_csv('/Users/gimdong-wan/Desktop/new_grid.csv',encoding='cp949')

# %% [markdown]
# #### 컬럼 정렬

# %%
new_grid = new_grid[['ID', '총인구', '유소년인구', '고령인구', '성폭력취약인구','건축물(30_34)', '건축물(35)', '건축물(30_)', '개별주택가격', '공시지가',
       '행정동코드', '가로등', '공영주차장', '공중화장실', '교육시설', '대규모점포', '대부업현황', '룸살롱',
       '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집', '오락시설', '원룸_오피스텔',
       '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도', '행정동면적', 'GRADE_전체']]

# %%
new_grid.describe()
# Out:
#                총인구        유소년인구         고령인구      성폭력취약인구   건축물(30_34)  \
# count  2038.000000  2038.000000  2038.000000  2038.000000  2038.000000
# mean    321.530913    36.866045    54.807655    25.466143     2.516683
# std     584.911843    87.017619   100.922453    50.795658     8.963323
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%      27.000000     0.000000     8.000000     0.000000     0.000000
# 75%     390.000000    26.000000    65.000000    27.000000     1.000000
# max    3685.000000   754.000000  1081.000000   357.000000   177.000000
#
#            건축물(35)     건축물(30_)        개별주택가격          공시지가          가로등  ...  \
# count  2038.000000  2038.000000  2.038000e+03  2.038000e+03  2038.000000  ...
# mean     11.052502    13.569185  1.104896e+08  3.147824e+05     7.247792  ...
# std      28.435282    32.395247  1.578595e+08  3.784582e+05    11.024493  ...
# min       0.000000     0.000000  0.000000e+00  0.000000e+00     0.000000  ...
# 25%       0.000000     0.000000  0.000000e+00  5.793375e+04     0.000000  ...
# 50%       1.000000     1.000000  7.503846e+07  1.650040e+05     0.000000  ...
# 75%       5.000000     7.000000  1.475442e+08  4.863058e+05    12.000000  ...
# max     252.000000   259.000000  4.706000e+09  3.253211e+06    82.000000  ...
#
#               오락시설      원룸_오피스텔          음식점        자율방범대          파출소  \
# count  2038.000000  2038.000000  2038.000000  2038.000000  2038.000000
# mean      0.405299     4.285574     5.856722     0.023553     0.009323
# std       1.436809    13.509316    13.640956     0.151687     0.096127
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     1.000000     4.000000     0.000000     0.000000
# max      23.000000   206.000000   161.000000     1.000000     1.000000
#
#               cctv          신호등         횡단보도        행정동면적     GRADE_전체
# count  2038.000000  2038.000000  2038.000000  2038.000000  2038.000000
# mean      0.658489     1.865554     3.371443    12.178837     1.386163
# std       1.116289     3.599703     5.647292     8.712301     1.904325
# min       0.000000     0.000000     0.000000     0.760000     0.000000
# 25%       0.000000     0.000000     0.000000     4.780000     0.000000
# 50%       0.000000     0.000000     0.000000    12.140000     0.000000
# 75%       1.000000     2.000000     5.000000    15.700000     2.000000
# max       7.000000    26.000000    56.000000    26.600000    10.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# #### 전체적으로 2~3사분위수에도 0이 많은 편향된 데이터임을 알 수 있음. 이후 스케일링이 필요하며 이상치 탐색이 필요함.

# %% [markdown]
# #### 타겟변수가 서열형이므로, Spearman 상관계수 이용

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(new_grid.corr(method = 'spearman'), annot=True)
plt.show()

# %% [markdown]
# ### 전체 변수 간 상관관계
#  - 인구 사회학적 변수는 변수간 상관관계가 크며, 이는 다중공선성 제거를 위해 변수를 선택할 필요가 있다. 또한, 대부분 범죄 등급과도 큰 상관관계를 보이고 있다.
#
# #### 종속변수 (3대범죄)를 기반으로 한 상관계수 확인
#
# - `인구` : 총인구 (0.69),성폭력취약인구(0.72), 유소년인구(0.69), 고령인구(0.68)
# - `토지` : 30년 이상35년 미만 건축물(0.4), 35년 이상건축물(0.28), 30년 이상 건축물 (0.33),개별주택가격 (0.38), 공시지가(0.68)
# - `시설물` : 가로등(0.54), 공영주차장(0.22), 공중화장실(0.28), 교육시설(0.64), 대규모점포(0.18), 대부업체현황(0.22), 룸살롱(0.26), 버스정류장(0.4), 보안등(0.26), 상가(0.76), 숙박업소(0.24), 술집(0.57), 어린이보호구역(0.23), 어린이집(0.39), 오락시설(0.52), 원룸_오피스텔(0.61), 음식점(0.71), 자율방범대(0.17), 파출소(0.12), cctv(0.56), 신호등(0.47), 횡단보도(0.65)

# %%
new_grid.shape
# Out:
# (2038, 35)

# %%
new_grid.columns
# Out:
# Index(['ID', '총인구', '유소년인구', '고령인구', '성폭력취약인구', '건축물(30_34)', '건축물(35)',
#        '건축물(30_)', '개별주택가격', '공시지가', '행정동코드', '가로등', '공영주차장', '공중화장실', '교육시설',
#        '대규모점포', '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호',
#        '어린이집', '오락시설', '원룸_오피스텔', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
#        '행정동면적', 'GRADE_전체'],
#       dtype='object')

# %%
def hist(x) : 
    plt.hist(new_grid[x])
    plt.xlabel(x)

# %%
def scatter(x) : 
    plt.plot(x,'GRADE_전체', linestyle='none', marker='o', markersize=3, color='blue', data = new_grid)
    plt.xlabel(x)

# %%
plt.subplot(221)
hist('총인구')

plt.subplot(222)
hist('유소년인구')

plt.subplot(223)
hist('고령인구')

plt.subplot(224)
hist('성폭력취약인구')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
scatter('총인구')

plt.subplot(222)
scatter('유소년인구')

plt.subplot(223)
scatter('고령인구')

plt.subplot(224)
scatter('성폭력취약인구')

plt.tight_layout()
plt.show()

# %%
plt.subplot(231)
hist('건축물(30_34)')

plt.subplot(232)
hist('건축물(35)')

plt.subplot(233)
hist('건축물(30_)')

plt.subplot(234)
hist('공시지가')

plt.subplot(235)
hist('개별주택가격')

plt.tight_layout()
plt.show()

# %%
plt.subplot(231)
scatter('건축물(30_34)')

plt.subplot(232)
scatter('건축물(35)')

plt.subplot(233)
scatter('건축물(30_)')

plt.subplot(234)
scatter('공시지가')

plt.subplot(235)
scatter('개별주택가격')

plt.tight_layout()
plt.show()

# %%
plt.subplot(331)
hist('가로등')

plt.subplot(332)
hist('공영주차장')

plt.subplot(333)
hist('공중화장실')

plt.subplot(334)
hist('교육시설')

plt.subplot(335)
hist('보안등')

plt.subplot(336)
hist('대규모점포')

plt.subplot(337)
hist('대부업현황')

plt.subplot(338)
hist('룸살롱')

plt.subplot(339)
hist('버스정류장')

plt.tight_layout()
plt.show()

# %%
plt.subplot(331)
scatter('가로등')

plt.subplot(332)
scatter('공영주차장')

plt.subplot(333)
scatter('공중화장실')

plt.subplot(334)
scatter('교육시설')

plt.subplot(335)
scatter('보안등')

plt.subplot(336)
scatter('대규모점포')

plt.subplot(337)
scatter('대부업현황')

plt.subplot(338)
scatter('룸살롱')

plt.subplot(339)
scatter('버스정류장')

plt.tight_layout()
plt.show()

# %%
plt.subplot(331)
hist('음식점')

plt.subplot(332)
hist('상가')

plt.subplot(333)
hist('숙박업소')

plt.subplot(334)
hist('술집')

plt.subplot(335)
hist('어린이보호')

plt.subplot(336)
hist('어린이집')

plt.subplot(337)
hist('오락시설')

plt.subplot(338)
hist('원룸_오피스텔')

plt.subplot(339)
hist('cctv')

plt.tight_layout()
plt.show()

# %%
plt.subplot(331)
scatter('음식점')

plt.subplot(332)
scatter('상가')

plt.subplot(333)
scatter('숙박업소')

plt.subplot(334)
scatter('술집')

plt.subplot(335)
scatter('어린이보호')

plt.subplot(336)
scatter('어린이집')

plt.subplot(337)
scatter('오락시설')

plt.subplot(338)
scatter('원룸_오피스텔')

plt.subplot(339)
scatter('cctv')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
hist('자율방범대')

plt.subplot(222)
hist('파출소')

plt.subplot(223)
hist('신호등')

plt.subplot(224)
hist('횡단보도')

plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
scatter('자율방범대')

plt.subplot(222)
scatter('파출소')

plt.subplot(223)
scatter('신호등')

plt.subplot(224)
scatter('횡단보도')

plt.tight_layout()
plt.show()

# %%
new_grid = new_grid[new_grid['개별주택가격']<4000000000]

# %% [markdown]
# #### 행정동면적, ID, 행정동 코드는 분석에서 제외
# #### 최대값이 50미만인 변수는 MinMaxScale
# #### 최대값이 50이상인 변수는 StandardScale

# %%
standard_feats = new_grid.dtypes[new_grid.dtypes != "object"].index.tolist()
standard_feats.remove('GRADE_전체')
standard_feats.remove('공영주차장')
standard_feats.remove('공중화장실')
standard_feats.remove('대규모점포')
standard_feats.remove('대부업현황')
standard_feats.remove('룸살롱')
standard_feats.remove('버스정류장')
standard_feats.remove('숙박업소')
standard_feats.remove('술집')
standard_feats.remove('어린이집')
standard_feats.remove('오락시설')
standard_feats.remove('cctv')
standard_feats.remove('자율방범대')
standard_feats.remove('파출소')


min_max_feats = list(new_grid.loc[:,['공영주차장','공중화장실','대규모점포','대부업현황','룸살롱','버스정류장','숙박업소','술집','어린이집','오락시설','cctv']].columns)
print("Number of Minmax features :", len(min_max_feats))
print("Number of Standard features: ", len(numerical_feats))

categorical_feats = new_grid.dtypes[new_grid.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Minmax features : 11
# Number of Standard features:  19
# Number of Categorical features:  2

# %%
scaler = StandardScaler()
new_grid[standard_feats] = scaler.fit_transform(new_grid[standard_feats])

# %%
scaler = MinMaxScaler()
new_grid[min_max_feats] = scaler.fit_transform(new_grid[min_max_feats])

# %% [markdown]
# ### 변수 선택을 위한 분산분석 실시

# %%
new_grid.loc[(new_grid['GRADE_전체']==0),'범죄빈도_4'] = 0
new_grid.loc[(new_grid['GRADE_전체']>0)&(new_grid['GRADE_전체']<4),'범죄빈도_4'] = 1
new_grid.loc[(new_grid['GRADE_전체']>=4)&(new_grid['GRADE_전체']<8),'범죄빈도_4'] = 2
new_grid.loc[(new_grid['GRADE_전체']>=8)&(new_grid['GRADE_전체']<11),'범죄빈도_4'] = 3

# %%
group_1 = new_grid[new_grid['범죄빈도_4'] == 0]
group_2 = new_grid[new_grid['범죄빈도_4'] == 1]
group_3 = new_grid[new_grid['범죄빈도_4'] == 2]
group_4 = new_grid[new_grid['범죄빈도_4'] == 3]

# %%
def anova(x):
    F_statistic, pVal = stats.f_oneway(group_1[x], group_2[x], group_3[x], group_4[x])

    print(x,' 데이터의 일원분산분석 결과 : F={0:.1f}, p={1:.5f}'.format(F_statistic, pVal))
    if pVal < 0.05:
        print('P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.')

# %%
anova('총인구')
anova('유소년인구')
anova('고령인구')
anova('성폭력취약인구')
anova('건축물(30_34)')
anova('건축물(35)')
anova('건축물(30_)')
anova('개별주택가격')
anova('공시지가')
anova('가로등')
anova('보안등')
anova('공중화장실')
anova('버스정류장')
anova('공영주차장')
anova('교육시설')
anova('대규모점포')
anova('대부업현황')
anova('룸살롱')
anova('버스정류장')
anova('보안등')
anova('상가')
anova('숙박업소')
anova('술집')
anova('어린이보호')
anova('어린이집')
anova('오락시설')
anova('원룸_오피스텔')
anova('음식점')
anova('자율방범대')
anova('파출소')
anova('cctv')
anova('신호등')
anova('횡단보도')
# Out:
# 총인구  데이터의 일원분산분석 결과 : F=254.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 유소년인구  데이터의 일원분산분석 결과 : F=106.9, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 고령인구  데이터의 일원분산분석 결과 : F=254.5, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 성폭력취약인구  데이터의 일원분산분석 결과 : F=252.0, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 건축물(30_34)  데이터의 일원분산분석 결과 : F=44.7, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 건축물(35)  데이터의 일원분산분석 결과 : F=82.7, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 건축물(30_)  데이터의 일원분산분석 결과 : F=98.9, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 개별주택가격  데이터의 일원분산분석 결과 : F=94.8, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 공시지가  데이터의 일원분산분석 결과 : F=332.0, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 가로등  데이터의 일원분산분석 결과 : F=214.3, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 보안등  데이터의 일원분산분석 결과 : F=77.3, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 공중화장실  데이터의 일원분산분석 결과 : F=37.1, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 버스정류장  데이터의 일원분산분석 결과 : F=113.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 공영주차장  데이터의 일원분산분석 결과 : F=55.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 교육시설  데이터의 일원분산분석 결과 : F=143.3, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 대규모점포  데이터의 일원분산분석 결과 : F=26.0, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 대부업현황  데이터의 일원분산분석 결과 : F=32.3, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 룸살롱  데이터의 일원분산분석 결과 : F=94.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 버스정류장  데이터의 일원분산분석 결과 : F=113.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 보안등  데이터의 일원분산분석 결과 : F=77.3, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 상가  데이터의 일원분산분석 결과 : F=380.8, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 숙박업소  데이터의 일원분산분석 결과 : F=90.5, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 술집  데이터의 일원분산분석 결과 : F=316.1, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 어린이보호  데이터의 일원분산분석 결과 : F=30.8, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 어린이집  데이터의 일원분산분석 결과 : F=73.8, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 오락시설  데이터의 일원분산분석 결과 : F=230.1, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 원룸_오피스텔  데이터의 일원분산분석 결과 : F=103.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 음식점  데이터의 일원분산분석 결과 : F=386.8, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 자율방범대  데이터의 일원분산분석 결과 : F=16.1, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 파출소  데이터의 일원분산분석 결과 : F=10.6, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# cctv  데이터의 일원분산분석 결과 : F=224.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 신호등  데이터의 일원분산분석 결과 : F=97.9, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.
# 횡단보도  데이터의 일원분산분석 결과 : F=257.4, p=0.00000
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.

# %%
def compare(x,y):
    comp = MultiComparison(new_grid[x], new_grid[y])
    result = comp.allpairtest(scipy.stats.ttest_ind, method='bonf')
    return result[0]

# %%
compare('총인구','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('유소년인구','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('고령인구','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('성폭력취약인구','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('건축물(30_34)','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('건축물(35)','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('건축물(30_)','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('개별주택가격','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('공시지가','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('공영주차장','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('공중화장실','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('교육시설','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('대규모점포','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('대부업현황','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('룸살롱','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('버스정류장','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('보안등','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('상가','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('숙박업소','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('술집','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('어린이보호','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('어린이집','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('오락시설','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('원룸_오피스텔','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('음식점','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('자율방범대','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('파출소','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('cctv','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('신호등','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('횡단보도','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
compare('가로등','범죄빈도_4')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### 선택한 변수 :
# '공시지가','숙박업소','술집','오락시설','음식점','룸살롱','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔','개별주택가격','건축물(35)',cctv

# %%
feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)

feature = new_grid[feature_list]
target = new_grid[['범죄빈도_4']]

# %% [markdown]
# ### 다중공선성 확인

# %%
#다중공선성확인
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(feature.values, i) for i in range(feature.shape[1])]
vif["features"] = feature.columns 
vif
# Out:
#     VIF Factor features
# 0     2.738755     공시지가
# 1     1.262619     숙박업소
# 2     3.902548       술집
# 3     2.447149     오락시설
# 4     4.820004      음식점
# 5     1.179794    공영주차장
# 6     1.955085      가로등
# 7     2.265432     횡단보도
# 8     1.832457      신호등
# 9     1.385258      총인구
# 10    1.472440  원룸_오피스텔
# 11    1.311177   개별주택가격
# 12    1.280578  건축물(35)
# 13    1.616756     cctv

# %% [markdown]
# ### 다중공선성 확인 결과 분석에 영향을 미칠만한 공선성은 없는 것으로 보임

# %%
len(new_grid)
# Out:
# 2037

# %%
407, 1630
# Out:
# (407, 1630)

# %% [markdown]
# #### 로지스틱, 데이터 100%

# %%
model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
model.fit(X=feature, y=target) # 학습수행 
y_pred = model.predict(X = feature)
acc=accuracy_score(target,y_pred)
print('accuracy =', acc) 
con_mat = confusion_matrix(y_true=target, y_pred=y_pred) 
con_mat
# Out:
# accuracy = 0.7201767304860088
# array([[956,  65,   1,   0],
#        [275, 376,  63,   0],
#        [ 12, 139, 131,   0],
#        [  1,   4,  10,   4]])

# %% [markdown]
# ### 로지스틱 다중분류 데이터 70%

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(feature,target, test_size=0.3, stratify=target, random_state=123456)

# %%
model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
model.fit(X=X_train, y=y_train) # 학습수행 
y_pred = model.predict(X = X_test)
acc=accuracy_score(y_test,y_pred)
print('accuracy =', acc) 
con_mat = confusion_matrix(y_true=y_test, y_pred=y_pred) 
con_mat
# Out:
# accuracy = 0.7156862745098039
# array([[286,  21,   0,   0],
#        [ 78, 113,  23,   0],
#        [  3,  44,  38,   0],
#        [  0,   1,   4,   1]])

# %% [markdown]
# ### 렌포 데이터 70%

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=123, verbose=0,
#                        warm_start=False)

# %%
from sklearn.metrics import accuracy_score

predicted = rf.predict(X_test)
accuracy = accuracy_score(y_test, predicted)

print(f'Out-of-bag score estimate: {rf.oob_score_:.3}')
print(f'Mean accuracy score: {accuracy:.3}')
con_mat = confusion_matrix(y_true=y_test, y_pred=predicted) 
con_mat
# Out:
# Out-of-bag score estimate: 0.711
# Mean accuracy score: 0.737
# array([[278,  29,   0,   0],
#        [ 63, 128,  23,   0],
#        [  1,  40,  44,   0],
#        [  0,   1,   4,   1]])

# %%
np.array(rf.feature_importances_)
# Out:
# array([0.19532302, 0.00907723, 0.03500708, 0.0147247 , 0.10204827,
#        0.00591885, 0.06610726, 0.08144204, 0.04653098, 0.19722408,
#        0.04964428, 0.09694907, 0.06125567, 0.03874745])

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(15,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')



plot_feature_importance(rf.feature_importances_,feature_list,'Randomforest')

# %%
feature_list
# Out:
# ['공시지가',
#  '숙박업소',
#  '술집',
#  '오락시설',
#  '음식점',
#  '공영주차장',
#  '가로등',
#  '횡단보도',
#  '신호등',
#  '총인구',
#  '원룸_오피스텔',
#  '개별주택가격',
#  '건축물(35)',
#  'cctv']

# %%
rf.feature_importances_
# Out:
# array([0.19532302, 0.00907723, 0.03500708, 0.0147247 , 0.10204827,
#        0.00591885, 0.06610726, 0.08144204, 0.04653098, 0.19722408,
#        0.04964428, 0.09694907, 0.06125567, 0.03874745])

# %% [markdown]
# ### GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import train_test_split

from sklearn.datasets import load_breast_cancer



cancer = load_breast_cancer()

# %%
gbc = GradientBoostingClassifier(random_state=0) # 기본값: max_depth=3, learning_rate=0.1

gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
predicted = gbc.predict(X_test)
accuracy = accuracy_score(y_test, predicted)

print(f'Out-of-bag score estimate: {rf.oob_score_:.3}')
print(f'Mean accuracy score: {accuracy:.3}')
con_mat = confusion_matrix(y_true=y_test, y_pred=predicted) 
con_mat
# Out:
# Out-of-bag score estimate: 0.711
# Mean accuracy score: 0.743
# array([[281,  26,   0,   0],
#        [ 61, 127,  25,   1],
#        [  1,  36,  45,   3],
#        [  0,   2,   2,   2]])

# %%
def plot_feature_importance(importance,names,model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')



plot_feature_importance(gbc.feature_importances_,feature_list,'GradiantBoostingModel')

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN = KNeighborsClassifier(n_neighbors = 4)
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %%
predicted = KNN.predict(X_test)
accuracy = accuracy_score(y_test, predicted)

print(f'Out-of-bag score estimate: {rf.oob_score_:.3}')
print(f'Mean accuracy score: {accuracy:.3}')
con_mat = confusion_matrix(y_true=y_test, y_pred=predicted) 
con_mat
# Out:
# Out-of-bag score estimate: 0.711
# Mean accuracy score: 0.69
# array([[282,  25,   0,   0],
#        [ 82, 109,  23,   0],
#        [  5,  48,  31,   1],
#        [  0,   1,   5,   0]])

# %% [markdown]
# ### k-fold 교차분석

# %% [markdown]
# #### 로지스틱

# %%
feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','룸살롱','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)

feature = new_grid[feature_list]
target = new_grid[['범죄빈도_4']]

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=False, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)
    feature = df_train[feature_list]
    target = df_train[['범죄빈도_4']]
    
    
    model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(target,y_pred1)
    acc_2=accuracy_score(df_test['범죄빈도_4'],y_pred2)
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 0.70288521, 검증 Accuracy = 0.78921569
# 학습 Accuracy = 0.72621240, 검증 Accuracy = 0.69362745
# 학습 Accuracy = 0.72085890, 검증 Accuracy = 0.69533170
# 학습 Accuracy = 0.74723926, 검증 Accuracy = 0.61916462
# 학습 Accuracy = 0.71533742, 검증 Accuracy = 0.72481572
# [0.78921569 0.69362745 0.6953317  0.61916462 0.72481572]
# 0.7044310353133882

# %% [markdown]
# #### 랜포

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=False, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)
    feature = df_train[feature_list]
    target = df_train[['범죄빈도_4']]
    
    
    model =  RandomForestClassifier(n_estimators=100, oob_score=True, random_state=0)
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(y_pred1,target)
    acc_2=accuracy_score(df_test['범죄빈도_4'],y_pred2)
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 1.00000000, 검증 Accuracy = 0.80637255
# 학습 Accuracy = 0.99938613, 검증 Accuracy = 0.73284314
# 학습 Accuracy = 0.99938650, 검증 Accuracy = 0.66339066
# 학습 Accuracy = 1.00000000, 검증 Accuracy = 0.64619165
# 학습 Accuracy = 0.99938650, 검증 Accuracy = 0.72235872
# [0.80637255 0.73284314 0.66339066 0.64619165 0.72235872]
# 0.7142313436431084

# %% [markdown]
# #### GBM

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=False, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)
    feature = df_train[feature_list]
    target = df_train[['범죄빈도_4']]
    
    
    model =  GradientBoostingClassifier(random_state=0)
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(y_pred1,target)
    acc_2=accuracy_score(df_test['범죄빈도_4'],y_pred2)
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 0.86740331, 검증 Accuracy = 0.79901961
# 학습 Accuracy = 0.87783917, 검증 Accuracy = 0.72058824
# 학습 Accuracy = 0.87791411, 검증 Accuracy = 0.67813268
# 학습 Accuracy = 0.88527607, 검증 Accuracy = 0.63390663
# 학습 Accuracy = 0.87914110, 검증 Accuracy = 0.70761671
# [0.79901961 0.72058824 0.67813268 0.63390663 0.70761671]
# 0.707852772558655

# %% [markdown]
# ### KNN

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=False, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)
    feature = df_train[feature_list]
    target = df_train[['범죄빈도_4']]
    
    
    model = KNeighborsClassifier(n_neighbors = 4)
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(y_pred1,target)
    acc_2=accuracy_score(df_test['범죄빈도_4'],y_pred2)
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 0.74831185, 검증 Accuracy = 0.75735294
# 학습 Accuracy = 0.76058932, 검증 Accuracy = 0.70833333
# 학습 Accuracy = 0.76134969, 검증 Accuracy = 0.62407862
# 학습 Accuracy = 0.77177914, 검증 Accuracy = 0.58968059
# 학습 Accuracy = 0.75276074, 검증 Accuracy = 0.64864865
# [0.75735294 0.70833333 0.62407862 0.58968059 0.64864865]
# 0.6656188273835333

# %%
plt.figure(figsize=(10,8))
x_label = ['Random Forest','Gradient Boosting','Logistic Regression', 'KNN']
x = np.arange(len(x_label))  # x = [0, 1, 2, 3, 4, 5]
y_1 = [71.4, 70.8, 70.4, 66.6]

# 넓이 지정
width = 0.35

# subplots 생성
fig, axes = plt.subplots()

# 넓이 설정
axes.barh(x - width/2, y_1, width, alpha = 0.5, color = "green")

# ticks & label 설정
plt.yticks(x)
axes.set_yticklabels(x_label)
plt.xlabel('Accuracy')

# title
plt.title('Model Accuracy')


plt.show()

# %%
from pycaret.classification import *

# %%
feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','룸살롱','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv','범죄빈도_4']].columns)
feature = new_grid[feature_list]

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = feature,
            train_size = 0.7,
            target = '범죄빈도_4',
            use_gpu = False, 
            session_id = 123,
           fold_shuffle = True,
           remove_multicollinearity = True, multicollinearity_threshold = 0.6)
# Out:
# <style  type="text/css" >
# #T_48490e82_0513_11ec_b056_acbc32d61fabrow42_col1,#T_48490e82_0513_11ec_b056_acbc32d61fabrow44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_48490e82_0513_11ec_b056_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow1_col1" class="data row1 col1" >범죄빈도_4</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow4_col1" class="data row4 col1" >(2037, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow6_col1" class="data row6 col1" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow11_col1" class="data row11 col1" >(1425, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow12_col1" class="data row12 col1" >(612, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_48490e82_0513_11ec_b056_acbc32d61fablevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_48490e82_0513_11ec_b056_acbc32d61fabrow18_col0" class="data row18 col0" >Use GPU</td>

# %%
best_5 = compare_models(sort = 'Accuracy', n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_a5ce5fb8_0517_11ec_b056_acbc32d61fab th {
#           text-align: left;
#     }#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col0,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col3,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow11_col0,#T_a5ce5fb8_0517_ ...
#             text-align:  left;
#             text-align:  left;
#         }#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col1,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col4,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col5,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col6,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col7,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col2,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow0_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow1_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow2_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow3_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow4_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow5_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow6_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow7_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow8_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow10_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow11_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow12_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow13_col8,#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_a5ce5fb8_0517_11ec_b056_acbc32d61fabrow9_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_a5ce5fb8_0517_11ec_b056_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a5ce5fb8_0517_11ec_b056_acbc32d61fablevel0_row0" class="row_heading level0 row0" >gbc</th>

# %%
blended = blend_models(estimator_list = best_5, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col0,#T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col1,#T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col2,#T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col3,#T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col4,#T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col5,#T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col6{
#             background:  yellow;
#         }</style><table id="T_adb283b2_0517_11ec_b056_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col0" class="data row0 col0" >0.6912</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col1" class="data row0 col1" >0.8334</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col2" class="data row0 col2" >0.4814</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col3" class="data row0 col3" >0.6739</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col4" class="data row0 col4" >0.6792</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col5" class="data row0 col5" >0.4761</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow0_col6" class="data row0 col6" >0.4798</td>
#             </tr>
#             <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col0" class="data row1 col0" >0.6912</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col1" class="data row1 col1" >0.8409</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col2" class="data row1 col2" >0.4721</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col3" class="data row1 col3" >0.6741</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col4" class="data row1 col4" >0.6799</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col5" class="data row1 col5" >0.4767</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow1_col6" class="data row1 col6" >0.4797</td>
#             </tr>
#             <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col0" class="data row2 col0" >0.7263</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col1" class="data row2 col1" >0.8507</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col2" class="data row2 col2" >0.4835</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col3" class="data row2 col3" >0.7074</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col4" class="data row2 col4" >0.7106</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col5" class="data row2 col5" >0.5290</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow2_col6" class="data row2 col6" >0.5345</td>
#             </tr>
#             <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col0" class="data row3 col0" >0.7053</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col1" class="data row3 col1" >0.8389</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col2" class="data row3 col2" >0.5372</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col3" class="data row3 col3" >0.6871</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col4" class="data row3 col4" >0.6893</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col5" class="data row3 col5" >0.4952</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow3_col6" class="data row3 col6" >0.5006</td>
#             </tr>
#             <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col0" class="data row4 col0" >0.6737</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col1" class="data row4 col1" >0.8239</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col2" class="data row4 col2" >0.4646</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col3" class="data row4 col3" >0.6597</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col4" class="data row4 col4" >0.6664</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col5" class="data row4 col5" >0.4580</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow4_col6" class="data row4 col6" >0.4584</td>
#             </tr>
#             <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col0" class="data row5 col0" >0.6975</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col1" class="data row5 col1" >0.8376</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col2" class="data row5 col2" >0.4878</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col3" class="data row5 col3" >0.6804</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col4" class="data row5 col4" >0.6851</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col5" class="data row5 col5" >0.4870</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow5_col6" class="data row5 col6" >0.4906</td>
#             </tr>
#             <tr>
#                         <th id="T_adb283b2_0517_11ec_b056_acbc32d61fablevel0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col0" class="data row6 col0" >0.0175</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col1" class="data row6 col1" >0.0088</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col2" class="data row6 col2" >0.0256</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col3" class="data row6 col3" >0.0160</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col4" class="data row6 col4" >0.0147</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col5" class="data row6 col5" >0.0241</td>
#                         <td id="T_adb283b2_0517_11ec_b056_acbc32d61fabrow6_col6" class="data row6 col6" >0.0257</td>
#             </tr>
#     </tbody></table>

# %%
rf = create_model('rf', cross_validation=True)
# Out:
# <style  type="text/css" >
# #T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col0,#T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col1,#T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col2,#T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col3,#T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col4,#T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col5,#T_b06a6854_0517_11ec_b056_acbc32d61fabrow10_col6{
#             background:  yellow;
#         }</style><table id="T_b06a6854_0517_11ec_b056_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col0" class="data row0 col0" >0.6573</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col1" class="data row0 col1" >0.8257</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col2" class="data row0 col2" >0.4682</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col3" class="data row0 col3" >0.6427</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col4" class="data row0 col4" >0.6494</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col5" class="data row0 col5" >0.4305</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow0_col6" class="data row0 col6" >0.4312</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col0" class="data row1 col0" >0.6853</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col1" class="data row1 col1" >0.8200</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col2" class="data row1 col2" >0.4539</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col3" class="data row1 col3" >0.6576</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col4" class="data row1 col4" >0.6657</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col5" class="data row1 col5" >0.4621</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow1_col6" class="data row1 col6" >0.4683</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col0" class="data row2 col0" >0.7832</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col1" class="data row2 col1" >0.8831</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col2" class="data row2 col2" >0.5749</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col3" class="data row2 col3" >0.7682</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col4" class="data row2 col4" >0.7725</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col5" class="data row2 col5" >0.6396</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow2_col6" class="data row2 col6" >0.6433</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col0" class="data row3 col0" >0.6573</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col1" class="data row3 col1" >0.8035</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col2" class="data row3 col2" >0.4398</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col3" class="data row3 col3" >0.6353</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col4" class="data row3 col4" >0.6420</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col5" class="data row3 col5" >0.4159</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow3_col6" class="data row3 col6" >0.4194</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col0" class="data row4 col0" >0.7273</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col1" class="data row4 col1" >0.8437</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col2" class="data row4 col2" >0.4943</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col3" class="data row4 col3" >0.7113</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col4" class="data row4 col4" >0.7161</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col5" class="data row4 col5" >0.5392</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow4_col6" class="data row4 col6" >0.5413</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col0" class="data row5 col0" >0.6761</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col1" class="data row5 col1" >0.8591</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col2" class="data row5 col2" >0.6777</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col3" class="data row5 col3" >0.6578</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col4" class="data row5 col4" >0.6640</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col5" class="data row5 col5" >0.4448</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow5_col6" class="data row5 col6" >0.4474</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col0" class="data row6 col0" >0.7042</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col1" class="data row6 col1" >0.8431</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col2" class="data row6 col2" >0.4400</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col3" class="data row6 col3" >0.6762</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col4" class="data row6 col4" >0.6855</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col5" class="data row6 col5" >0.4863</td>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow6_col6" class="data row6 col6" >0.4908</td>
#             </tr>
#             <tr>
#                         <th id="T_b06a6854_0517_11ec_b056_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b06a6854_0517_11ec_b056_acbc32d61fabrow7_co

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=False, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.loc[:,['공시지가','숙박업소','술집','오락시설','음식점','공영주차장','가로등','횡단보도','신호등','총인구','원룸_오피스텔'
                                   ,'개별주택가격','건축물(35)','cctv']].columns)
    feature = df_train[feature_list]
    target = df_train[['범죄빈도_4']]
    
    
    model =  RandomForestClassifier(n_estimators=100, oob_score=True, random_state=0)
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(y_pred1,target)
    acc_2=accuracy_score(df_test['범죄빈도_4'],y_pred2)
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
    
    def plot_feature_importance(importance,names,model_type):
    
        feature_importance = np.array(importance)
        feature_names = np.array(names)
    
        data={'feature_names':feature_names,'feature_importance':feature_importance}
        fi_df = pd.DataFrame(data)
    
        fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

        plt.figure(figsize=(10,8))
    
        sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    
        plt.title(model_type + ' Feature Importance')
        plt.xlabel('Feature Importance')
        plt.ylabel('Feature Names')



    plot_feature_importance(model.feature_importances_,feature_list,'Randomforest')
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 1.00000000, 검증 Accuracy = 0.80637255
# 학습 Accuracy = 0.99938613, 검증 Accuracy = 0.73284314
# 학습 Accuracy = 0.99938650, 검증 Accuracy = 0.66339066
# 학습 Accuracy = 1.00000000, 검증 Accuracy = 0.64619165
# 학습 Accuracy = 0.99938650, 검증 Accuracy = 0.72235872
# [0.80637255 0.73284314 0.66339066 0.64619165 0.72235872]
# 0.7142313436431084
