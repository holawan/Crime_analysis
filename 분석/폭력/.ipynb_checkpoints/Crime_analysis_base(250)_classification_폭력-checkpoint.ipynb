# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"
from IPython.display import Image

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from scipy import stats
import scipy 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from pycaret.regression import *
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
import pandas_profiling
import statsmodels.api as sm
from sklearn.decomposition import PCA
from statsmodels.miscmodels.ordinal_model import OrderedModel

# %%
grid_250 = pd.read_csv('/Users/gimdong-wan/Desktop/DataCampus/data/real_data/250grid_data.csv')

# %%
grid_250 = grid_250.fillna(0)

# %%
grid_250['성폭력취약인구'] = grid_250['고등여성인구']+grid_250['20대여성인구']
grid_250['건축물(30_)'] = grid_250['건축물(30_34)']+grid_250['건축물(35)']
grid_250['GRADE_폭력'] = grid_250['GRADE_폭력'].apply(lambda x: x-1 if x>0 else x)
grid_250['GRADE_절도'] = grid_250['GRADE_절도'].apply(lambda x: x-1 if x>0 else x)
grid_250['GRADE_성폭력'] = grid_250['GRADE_성폭력'].apply(lambda x: x-1 if x>0 else x)
grid_250 = grid_250.drop(columns = ['20대여성인구','고등여성인구','INDEX'])

# %% [markdown]
# ### 행정동별로 평균 범죄주의구간 등급 확인

# %%
feat_N = grid_250[(grid_250['총인구']==0)&(grid_250['건축물(30_34)']==0)&(grid_250['건축물(35)']==0)&(grid_250['가로등']==0)&(grid_250['공영주차장']==0)&(grid_250['공중화장실']==0)&(grid_250['숙박업소']==0)
        &(grid_250['대규모점포']==0)&(grid_250['대부업현황']==0)&(grid_250['상가']==0)&(grid_250['어린이보호']==0)&(grid_250['원룸_오피스텔']==0)&(grid_250['cctv']==0)&(grid_250['신호등']==0)&(grid_250['횡단보도']==0)
        &(grid_250['버스정류장']==0)&(grid_250['개별주택가격']==0)] #target 제외 모든 변수가 0인 row
feat_Y = grid_250[(grid_250['총인구']>0)|(grid_250['건축물(30_34)']>0)|(grid_250['건축물(35)']>0)|(grid_250['가로등']>0)|(grid_250['공영주차장']>0)|(grid_250['공중화장실']>0)|(grid_250['숙박업소']>0)
        |(grid_250['대규모점포']>0)|(grid_250['대부업현황']>0)|(grid_250['상가']>0)|(grid_250['어린이보호']>0)|(grid_250['원룸_오피스텔']>0)|(grid_250['cctv']>0)|(grid_250['신호등']>0)|(grid_250['횡단보도']>0)
        |(grid_250['버스정류장']>0)|(grid_250['개별주택가격']>0)] #target 제외 모든 변수가 0보다 큰 row

# %% [markdown]
# - 모든 피쳐가 0인 행이 `1460`개이고, 한 피쳐라도 0보다 큰 행은 `2038`개 (공시지가와 타겟 제외)

# %% [markdown]
# - 폭력등급이 0보다 큰 로우는 900개, 절도 등급이 0보다 큰 로우는 836개, 성폭력 등급이 0보다 큰 로우는 303개가 있다.
# - 모든 피쳐가 0임에도 불구하고(1460개의 피쳐), 폭력등급이 있는 로우는 19개, 절도 13개, 성폭력 4개가 있었다.

# %% [markdown]
# ### 피쳐가 없는 격자들 지도에서 탐색해보기

# %%
new_grid = feat_Y

# %%
new_grid.columns
# Out:
# Index(['ID', '총인구', '유소년인구', '고령인구', '건축물(30_34)', '건축물(35)', '개별주택가격', '공시지가',
#        '행정동코드', '가로등', '공영주차장', '공중화장실', '교육시설', '대규모점포', '대부업현황', '룸살롱',
#        '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집', '오락시설', '원룸_오피스텔',
#        '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도', 'GRADE_폭력', 'GRADE_절도',
#        'GRADE_성폭력', '성폭력취약인구', '건축물(30_)'],
#       dtype='object')

# %%
numerical_feats = new_grid.dtypes[new_grid.dtypes != "object"].index.tolist()
numerical_feats.remove('GRADE_폭력')
numerical_feats.remove('GRADE_절도')
numerical_feats.remove('GRADE_성폭력')
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = new_grid.dtypes[new_grid.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  31
# Number of Categorical features:  2

# %%
feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력']).columns)
feature = new_grid[feature_list]
target = new_grid[['GRADE_폭력']]

# %%
new_grid.columns
# Out:
# Index(['ID', '총인구', '유소년인구', '고령인구', '건축물(30_34)', '건축물(35)', '개별주택가격', '공시지가',
#        '행정동코드', '가로등', '공영주차장', '공중화장실', '교육시설', '대규모점포', '대부업현황', '룸살롱',
#        '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집', '오락시설', '원룸_오피스텔',
#        '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도', 'GRADE_폭력', 'GRADE_절도',
#        'GRADE_성폭력', '성폭력취약인구', '건축물(30_)'],
#       dtype='object')

# %%
def mean_compare(x,crime) : 
    for i in range(11) :
        print(crime,'등급이',i,'인 격자의 평균',x,':',new_grid.query('GRADE_'+crime+'=='+str(i))[x].mean())
    print('------------------------------------------------')

# %%
mean_compare('총인구','폭력')

mean_compare('건축물(30_)','폭력')

mean_compare('개별주택가격','폭력')

mean_compare('공시지가','폭력')

mean_compare('가로등','폭력')

mean_compare('보안등','폭력')

mean_compare('공중화장실','폭력')

mean_compare('공영주차장','폭력')

mean_compare('교육시설','폭력')

mean_compare('대규모점포','폭력')

mean_compare('대부업현황','폭력')

mean_compare('룸살롱','폭력')

mean_compare('버스정류장','폭력')

mean_compare('상가','폭력')

mean_compare('숙박업소','폭력')

mean_compare('술집','폭력')

mean_compare('어린이보호','폭력')

mean_compare('어린이집','폭력')

mean_compare('오락시설','폭력')

mean_compare('원룸_오피스텔','폭력')

mean_compare('음식점','폭력')

mean_compare('자율방범대','폭력')

mean_compare('파출소','폭력')

mean_compare('cctv','폭력')

mean_compare('신호등','폭력')

mean_compare('횡단보도','폭력')

mean_compare('유소년인구','폭력')

mean_compare('고령인구','폭력')
# Out:
# 폭력 등급이 0 인 격자의 평균 총인구 : 68.81071737251513
# 폭력 등급이 1 인 격자의 평균 총인구 : 341.26073619631904
# 폭력 등급이 2 인 격자의 평균 총인구 : 751.8392857142857
# 폭력 등급이 3 인 격자의 평균 총인구 : 928.7236842105264
# 폭력 등급이 4 인 격자의 평균 총인구 : 671.15625
# 폭력 등급이 5 인 격자의 평균 총인구 : 872.0632911392405
# 폭력 등급이 6 인 격자의 평균 총인구 : 1030.888888888889
# 폭력 등급이 7 인 격자의 평균 총인구 : 1159.96
# 폭력 등급이 8 인 격자의 평균 총인구 : 934.4
# 폭력 등급이 9 인 격자의 평균 총인구 : 529.0
# 폭력 등급이 10 인 격자의 평균 총인구 : 432.3333333333333
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 건축물(30_) : 2.9213483146067416
# 폭력 등급이 1 인 격자의 평균 건축물(30_) : 19.282208588957054
# 폭력 등급이 2 인 격자의 평균 건축물(30_) : 35.589285714285715
# 폭력 등급이 3 인 격자의 평균 건축물(30_) : 26.68421052631579
# 폭력 등급이 4 인 격자의 평균 건축물(30_) : 37.046875
# 폭력 등급이 5 인 격자의 평균 건축물(30_) : 33.55696202531646
# 폭력 등급이 6 인 격자의 평균 건축물(30_) : 28.57777777777778
# 폭력 등급이 7 인 격자의 평균 건축물(30_) : 40.36
# 폭력 등급이 8 인 격자의 평균 건축물(30_) : 6.6
# 폭력 등급이 9 인 격자의 평균 건축물(30_) : 5.333333333333333
# 폭력 등급이 10 인 격자의 평균 건축물(30_) : 34.833333333333336
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 개별주택가격 : 77909735.4883319
# 폭력 등급이 1 인 격자의 평균 개별주택가격 : 121668489.72392638
# 폭력 등급이 2 인 격자의 평균 개별주택가격 : 173997335.4017857
# 폭력 등급이 3 인 격자의 평균 개별주택가격 : 164665433.31578946
# 폭력 등급이 4 인 격자의 평균 개별주택가격 : 158774221.9453125
# 폭력 등급이 5 인 격자의 평균 개별주택가격 : 179518213.69620255
# 폭력 등급이 6 인 격자의 평균 개별주택가격 : 181838115.31111112
# 폭력 등급이 7 인 격자의 평균 개별주택가격 : 184340661.52
# 폭력 등급이 8 인 격자의 평균 개별주택가격 : 304785773.8
# 폭력 등급이 9 인 격자의 평균 개별주택가격 : 287426565.6666667
# 폭력 등급이 10 인 격자의 평균 개별주택가격 : 195508351.66666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 공시지가 : 142005.3794295592
# 폭력 등급이 1 인 격자의 평균 공시지가 : 346906.96625766874
# 폭력 등급이 2 인 격자의 평균 공시지가 : 605542.2410714285
# 폭력 등급이 3 인 격자의 평균 공시지가 : 662625.1710526316
# 폭력 등급이 4 인 격자의 평균 공시지가 : 646033.2421875
# 폭력 등급이 5 인 격자의 평균 공시지가 : 705720.9367088608
# 폭력 등급이 6 인 격자의 평균 공시지가 : 659845.7333333333
# 폭력 등급이 7 인 격자의 평균 공시지가 : 537838.24
# 폭력 등급이 8 인 격자의 평균 공시지가 : 862917.4
# 폭력 등급이 9 인 격자의 평균 공시지가 : 595338.3333333334
# 폭력 등급이 10 인 격자의 평균 공시지가 : 1318516.5
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 가로등 : 2.7536732929991357
# 폭력 등급이 1 인 격자의 평균 가로등 : 9.11963190184049
# 폭력 등급이 2 인 격자의 평균 가로등 : 15.303571428571429
# 폭력 등급이 3 인 격자의 평균 가로등 : 15.125
# 폭력 등급이 4 인 격자의 평균 가로등 : 16.046875
# 폭력 등급이 5 인 격자의 평균 가로등 : 15.620253164556962
# 폭력 등급이 6 인 격자의 평균 가로등 : 16.8
# 폭력 등급이 7 인 격자의 평균 가로등 : 10.64
# 폭력 등급이 8 인 격자의 평균 가로등 : 20.6
# 폭력 등급이 9 인 격자의 평균 가로등 : 20.333333333333332
# 폭력 등급이 10 인 격자의 평균 가로등 : 20.833333333333332
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 보안등 : 2.171132238547969
# 폭력 등급이 1 인 격자의 평균 보안등 : 6.282208588957055
# 폭력 등급이 2 인 격자의 평균 보안등 : 17.955357142857142
# 폭력 등급이 3 인 격자의 평균 보안등 : 11.842105263157896
# 폭력 등급이 4 인 격자의 평균 보안등 : 8.703125
# 폭력 등급이 5 인 격자의 평균 보안등 : 4.430379746835443
# 폭력 등급이 6 인 격자의 평균 보안등 : 2.111111111111111
# 폭력 등급이 7 인 격자의 평균 보안등 : 2.48
# 폭력 등급이 8 인 격자의 평균 보안등 : 0.8
# 폭력 등급이 9 인 격자의 평균 보안등 : 0.3333333333333333
# 폭력 등급이 10 인 격자의 평균 보안등 : 1.1666666666666667
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 공중화장실 : 0.055315471045808126
# 폭력 등급이 1 인 격자의 평균 공중화장실 : 0.18404907975460122
# 폭력 등급이 2 인 격자의 평균 공중화장실 : 0.25892857142857145
# 폭력 등급이 3 인 격자의 평균 공중화장실 : 0.3157894736842105
# 폭력 등급이 4 인 격자의 평균 공중화장실 : 0.515625
# 폭력 등급이 5 인 격자의 평균 공중화장실 : 0.3670886075949367
# 폭력 등급이 6 인 격자의 평균 공중화장실 : 0.28888888888888886
# 폭력 등급이 7 인 격자의 평균 공중화장실 : 0.28
# 폭력 등급이 8 인 격자의 평균 공중화장실 : 0.0
# 폭력 등급이 9 인 격자의 평균 공중화장실 : 1.3333333333333333
# 폭력 등급이 10 인 격자의 평균 공중화장실 : 0.6666666666666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 공영주차장 : 0.006050129645635264
# 폭력 등급이 1 인 격자의 평균 공영주차장 : 0.018404907975460124
# 폭력 등급이 2 인 격자의 평균 공영주차장 : 0.07142857142857142
# 폭력 등급이 3 인 격자의 평균 공영주차장 : 0.10526315789473684
# 폭력 등급이 4 인 격자의 평균 공영주차장 : 0.15625
# 폭력 등급이 5 인 격자의 평균 공영주차장 : 0.11392405063291139
# 폭력 등급이 6 인 격자의 평균 공영주차장 : 0.1111111111111111
# 폭력 등급이 7 인 격자의 평균 공영주차장 : 0.04
# 폭력 등급이 8 인 격자의 평균 공영주차장 : 0.4
# 폭력 등급이 9 인 격자의 평균 공영주차장 : 0.3333333333333333
# 폭력 등급이 10 인 격자의 평균 공영주차장 : 0.8333333333333334
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 교육시설 : 0.11668107173725151
# 폭력 등급이 1 인 격자의 평균 교육시설 : 1.3558282208588956
# 폭력 등급이 2 인 격자의 평균 교육시설 : 4.991071428571429
# 폭력 등급이 3 인 격자의 평균 교육시설 : 5.7105263157894735
# 폭력 등급이 4 인 격자의 평균 교육시설 : 5.140625
# 폭력 등급이 5 인 격자의 평균 교육시설 : 6.569620253164557
# 폭력 등급이 6 인 격자의 평균 교육시설 : 8.4
# 폭력 등급이 7 인 격자의 평균 교육시설 : 3.36
# 폭력 등급이 8 인 격자의 평균 교육시설 : 2.6
# 폭력 등급이 9 인 격자의 평균 교육시설 : 7.333333333333333
# 폭력 등급이 10 인 격자의 평균 교육시설 : 2.6666666666666665
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 대규모점포 : 0.0
# 폭력 등급이 1 인 격자의 평균 대규모점포 : 0.012269938650306749
# 폭력 등급이 2 인 격자의 평균 대규모점포 : 0.0625
# 폭력 등급이 3 인 격자의 평균 대규모점포 : 0.039473684210526314
# 폭력 등급이 4 인 격자의 평균 대규모점포 : 0.046875
# 폭력 등급이 5 인 격자의 평균 대규모점포 : 0.13924050632911392
# 폭력 등급이 6 인 격자의 평균 대규모점포 : 0.06666666666666667
# 폭력 등급이 7 인 격자의 평균 대규모점포 : 0.04
# 폭력 등급이 8 인 격자의 평균 대규모점포 : 0.0
# 폭력 등급이 9 인 격자의 평균 대규모점포 : 0.0
# 폭력 등급이 10 인 격자의 평균 대규모점포 : 0.0
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 대부업현황 : 0.001728608470181504
# 폭력 등급이 1 인 격자의 평균 대부업현황 : 0.05214723926380368
# 폭력 등급이 2 인 격자의 평균 대부업현황 : 0.07142857142857142
# 폭력 등급이 3 인 격자의 평균 대부업현황 : 0.125
# 폭력 등급이 4 인 격자의 평균 대부업현황 : 0.1484375
# 폭력 등급이 5 인 격자의 평균 대부업현황 : 0.17721518987341772
# 폭력 등급이 6 인 격자의 평균 대부업현황 : 0.08888888888888889
# 폭력 등급이 7 인 격자의 평균 대부업현황 : 0.08
# 폭력 등급이 8 인 격자의 평균 대부업현황 : 0.0
# 폭력 등급이 9 인 격자의 평균 대부업현황 : 0.0
# 폭력 등급이 10 인 격자의 평균 대부업현황 : 0.3333333333333333
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 룸살롱 : 0.0
# 폭력 등급이 1 인 격자의 평균 룸살롱 : 0.03987730061349693
# 폭력 등급이 2 인 격자의 평균 룸살롱 : 0.07142857142857142
# 폭력 등급이 3 인 격자의 평균 룸살롱 : 0.09868421052631579
# 폭력 등급이 4 인 격자의 평균 룸살롱 : 0.078125
# 폭력 등급이 5 인 격자의 평균 룸살롱 : 0.8860759493670886
# 폭력 등급이 6 인 격자의 평균 룸살롱 : 0.6
# 폭력 등급이 7 인 격자의 평균 룸살롱 : 0.68
# 폭력 등급이 8 인 격자의 평균 룸살롱 : 5.4
# 폭력 등급이 9 인 격자의 평균 룸살롱 : 6.0
# 폭력 등급이 10 인 격자의 평균 룸살롱 : 11.666666666666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 버스정류장 : 0.08038029386343994
# 폭력 등급이 1 인 격자의 평균 버스정류장 : 0.37116564417177916
# 폭력 등급이 2 인 격자의 평균 버스정류장 : 0.6428571428571429
# 폭력 등급이 3 인 격자의 평균 버스정류장 : 0.5921052631578947
# 폭력 등급이 4 인 격자의 평균 버스정류장 : 0.5859375
# 폭력 등급이 5 인 격자의 평균 버스정류장 : 0.5443037974683544
# 폭력 등급이 6 인 격자의 평균 버스정류장 : 0.9555555555555556
# 폭력 등급이 7 인 격자의 평균 버스정류장 : 0.72
# 폭력 등급이 8 인 격자의 평균 버스정류장 : 1.0
# 폭력 등급이 9 인 격자의 평균 버스정류장 : 1.3333333333333333
# 폭력 등급이 10 인 격자의 평균 버스정류장 : 0.8333333333333334
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 상가 : 1.8202247191011236
# 폭력 등급이 1 인 격자의 평균 상가 : 11.843558282208589
# 폭력 등급이 2 인 격자의 평균 상가 : 35.57142857142857
# 폭력 등급이 3 인 격자의 평균 상가 : 47.69736842105263
# 폭력 등급이 4 인 격자의 평균 상가 : 51.8984375
# 폭력 등급이 5 인 격자의 평균 상가 : 55.49367088607595
# 폭력 등급이 6 인 격자의 평균 상가 : 66.73333333333333
# 폭력 등급이 7 인 격자의 평균 상가 : 49.68
# 폭력 등급이 8 인 격자의 평균 상가 : 44.6
# 폭력 등급이 9 인 격자의 평균 상가 : 92.33333333333333
# 폭력 등급이 10 인 격자의 평균 상가 : 126.0
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 숙박업소 : 0.019878997407087293
# 폭력 등급이 1 인 격자의 평균 숙박업소 : 0.10122699386503067
# 폭력 등급이 2 인 격자의 평균 숙박업소 : 0.49107142857142855
# 폭력 등급이 3 인 격자의 평균 숙박업소 : 0.35526315789473684
# 폭력 등급이 4 인 격자의 평균 숙박업소 : 0.328125
# 폭력 등급이 5 인 격자의 평균 숙박업소 : 0.8734177215189873
# 폭력 등급이 6 인 격자의 평균 숙박업소 : 0.3333333333333333
# 폭력 등급이 7 인 격자의 평균 숙박업소 : 1.76
# 폭력 등급이 8 인 격자의 평균 숙박업소 : 3.4
# 폭력 등급이 9 인 격자의 평균 숙박업소 : 5.0
# 폭력 등급이 10 인 격자의 평균 숙박업소 : 7.666666666666667
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 술집 : 0.024200518582541054
# 폭력 등급이 1 인 격자의 평균 술집 : 0.19938650306748465
# 폭력 등급이 2 인 격자의 평균 술집 : 0.7946428571428571
# 폭력 등급이 3 인 격자의 평균 술집 : 1.5789473684210527
# 폭력 등급이 4 인 격자의 평균 술집 : 2.2265625
# 폭력 등급이 5 인 격자의 평균 술집 : 2.759493670886076
# 폭력 등급이 6 인 격자의 평균 술집 : 4.0
# 폭력 등급이 7 인 격자의 평균 술집 : 3.04
# 폭력 등급이 8 인 격자의 평균 술집 : 8.4
# 폭력 등급이 9 인 격자의 평균 술집 : 16.333333333333332
# 폭력 등급이 10 인 격자의 평균 술집 : 24.5
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 어린이보호 : 0.049265341400172864
# 폭력 등급이 1 인 격자의 평균 어린이보호 : 0.1441717791411043
# 폭력 등급이 2 인 격자의 평균 어린이보호 : 0.24107142857142858
# 폭력 등급이 3 인 격자의 평균 어린이보호 : 0.2236842105263158
# 폭력 등급이 4 인 격자의 평균 어린이보호 : 0.2734375
# 폭력 등급이 5 인 격자의 평균 어린이보호 : 0.17721518987341772
# 폭력 등급이 6 인 격자의 평균 어린이보호 : 0.4444444444444444
# 폭력 등급이 7 인 격자의 평균 어린이보호 : 0.32
# 폭력 등급이 8 인 격자의 평균 어린이보호 : 0.4
# 폭력 등급이 9 인 격자의 평균 어린이보호 : 0.0
# 폭력 등급이 10 인 격자의 평균 어린이보호 : 0.16666666666666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 어린이집 : 0.06136560069144339
# 폭력 등급이 1 인 격자의 평균 어린이집 : 0.3374233128834356
# 폭력 등급이 2 인 격자의 평균 어린이집 : 0.5982142857142857
# 폭력 등급이 3 인 격자의 평균 어린이집 : 1.0
# 폭력 등급이 4 인 격자의 평균 어린이집 : 0.5703125
# 폭력 등급이 5 인 격자의 평균 어린이집 : 0.6582278481012658
# 폭력 등급이 6 인 격자의 평균 어린이집 : 1.1555555555555554
# 폭력 등급이 7 인 격자의 평균 어린이집 : 0.88
# 폭력 등급이 8 인 격자의 평균 어린이집 : 0.2
# 폭력 등급이 9 인 격자의 평균 어린이집 : 1.6666666666666667
# 폭력 등급이 10 인 격자의 평균 어린이집 : 0.16666666666666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 오락시설 : 0.014693171996542784
# 폭력 등급이 1 인 격자의 평균 오락시설 : 0.19938650306748465
# 폭력 등급이 2 인 격자의 평균 오락시설 : 0.7142857142857143
# 폭력 등급이 3 인 격자의 평균 오락시설 : 1.0592105263157894
# 폭력 등급이 4 인 격자의 평균 오락시설 : 1.3359375
# 폭력 등급이 5 인 격자의 평균 오락시설 : 1.3417721518987342
# 폭력 등급이 6 인 격자의 평균 오락시설 : 2.088888888888889
# 폭력 등급이 7 인 격자의 평균 오락시설 : 0.92
# 폭력 등급이 8 인 격자의 평균 오락시설 : 1.8
# 폭력 등급이 9 인 격자의 평균 오락시설 : 9.333333333333334
# 폭력 등급이 10 인 격자의 평균 오락시설 : 12.0
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 원룸_오피스텔 : 0.324114088159032
# 폭력 등급이 1 인 격자의 평균 원룸_오피스텔 : 3.5920245398773005
# 폭력 등급이 2 인 격자의 평균 원룸_오피스텔 : 10.678571428571429
# 폭력 등급이 3 인 격자의 평균 원룸_오피스텔 : 14.052631578947368
# 폭력 등급이 4 인 격자의 평균 원룸_오피스텔 : 15.390625
# 폭력 등급이 5 인 격자의 평균 원룸_오피스텔 : 10.974683544303797
# 폭력 등급이 6 인 격자의 평균 원룸_오피스텔 : 12.2
# 폭력 등급이 7 인 격자의 평균 원룸_오피스텔 : 12.72
# 폭력 등급이 8 인 격자의 평균 원룸_오피스텔 : 6.0
# 폭력 등급이 9 인 격자의 평균 원룸_오피스텔 : 19.333333333333332
# 폭력 등급이 10 인 격자의 평균 원룸_오피스텔 : 10.666666666666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 음식점 : 0.5851339671564391
# 폭력 등급이 1 인 격자의 평균 음식점 : 3.588957055214724
# 폭력 등급이 2 인 격자의 평균 음식점 : 9.955357142857142
# 폭력 등급이 3 인 격자의 평균 음식점 : 15.927631578947368
# 폭력 등급이 4 인 격자의 평균 음식점 : 18.5625
# 폭력 등급이 5 인 격자의 평균 음식점 : 20.89873417721519
# 폭력 등급이 6 인 격자의 평균 음식점 : 27.57777777777778
# 폭력 등급이 7 인 격자의 평균 음식점 : 18.68
# 폭력 등급이 8 인 격자의 평균 음식점 : 27.2
# 폭력 등급이 9 인 격자의 평균 음식점 : 53.666666666666664
# 폭력 등급이 10 인 격자의 평균 음식점 : 86.83333333333333
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 자율방범대 : 0.005185825410544511
# 폭력 등급이 1 인 격자의 평균 자율방범대 : 0.024539877300613498
# 폭력 등급이 2 인 격자의 평균 자율방범대 : 0.044642857142857144
# 폭력 등급이 3 인 격자의 평균 자율방범대 : 0.06578947368421052
# 폭력 등급이 4 인 격자의 평균 자율방범대 : 0.046875
# 폭력 등급이 5 인 격자의 평균 자율방범대 : 0.05063291139240506
# 폭력 등급이 6 인 격자의 평균 자율방범대 : 0.08888888888888889
# 폭력 등급이 7 인 격자의 평균 자율방범대 : 0.16
# 폭력 등급이 8 인 격자의 평균 자율방범대 : 0.0
# 폭력 등급이 9 인 격자의 평균 자율방범대 : 0.0
# 폭력 등급이 10 인 격자의 평균 자율방범대 : 0.16666666666666666
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 파출소 : 0.0
# 폭력 등급이 1 인 격자의 평균 파출소 : 0.012269938650306749
# 폭력 등급이 2 인 격자의 평균 파출소 : 0.008928571428571428
# 폭력 등급이 3 인 격자의 평균 파출소 : 0.02631578947368421
# 폭력 등급이 4 인 격자의 평균 파출소 : 0.046875
# 폭력 등급이 5 인 격자의 평균 파출소 : 0.012658227848101266
# 폭력 등급이 6 인 격자의 평균 파출소 : 0.06666666666666667
# 폭력 등급이 7 인 격자의 평균 파출소 : 0.0
# 폭력 등급이 8 인 격자의 평균 파출소 : 0.0
# 폭력 등급이 9 인 격자의 평균 파출소 : 0.0
# 폭력 등급이 10 인 격자의 평균 파출소 : 0.0
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 cctv : 0.18668971477960242
# 폭력 등급이 1 인 격자의 평균 cctv : 0.8251533742331288
# 폭력 등급이 2 인 격자의 평균 cctv : 1.4642857142857142
# 폭력 등급이 3 인 격자의 평균 cctv : 1.4473684210526316
# 폭력 등급이 4 인 격자의 평균 cctv : 1.5703125
# 폭력 등급이 5 인 격자의 평균 cctv : 1.5569620253164558
# 폭력 등급이 6 인 격자의 평균 cctv : 1.6888888888888889
# 폭력 등급이 7 인 격자의 평균 cctv : 2.24
# 폭력 등급이 8 인 격자의 평균 cctv : 0.8
# 폭력 등급이 9 인 격자의 평균 cctv : 0.6666666666666666
# 폭력 등급이 10 인 격자의 평균 cctv : 1.8333333333333333
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 신호등 : 0.7579948141745895
# 폭력 등급이 1 인 격자의 평균 신호등 : 2.539877300613497
# 폭력 등급이 2 인 격자의 평균 신호등 : 3.6160714285714284
# 폭력 등급이 3 인 격자의 평균 신호등 : 3.8026315789473686
# 폭력 등급이 4 인 격자의 평균 신호등 : 4.0234375
# 폭력 등급이 5 인 격자의 평균 신호등 : 3.7468354430379747
# 폭력 등급이 6 인 격자의 평균 신호등 : 4.4
# 폭력 등급이 7 인 격자의 평균 신호등 : 1.52
# 폭력 등급이 8 인 격자의 평균 신호등 : 3.4
# 폭력 등급이 9 인 격자의 평균 신호등 : 5.0
# 폭력 등급이 10 인 격자의 평균 신호등 : 5.833333333333333
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 횡단보도 : 1.0259291270527227
# 폭력 등급이 1 인 격자의 평균 횡단보도 : 4.180981595092025
# 폭력 등급이 2 인 격자의 평균 횡단보도 : 6.357142857142857
# 폭력 등급이 3 인 격자의 평균 횡단보도 : 6.782894736842105
# 폭력 등급이 4 인 격자의 평균 횡단보도 : 8.2421875
# 폭력 등급이 5 인 격자의 평균 횡단보도 : 7.30379746835443
# 폭력 등급이 6 인 격자의 평균 횡단보도 : 11.733333333333333
# 폭력 등급이 7 인 격자의 평균 횡단보도 : 7.52
# 폭력 등급이 8 인 격자의 평균 횡단보도 : 16.6
# 폭력 등급이 9 인 격자의 평균 횡단보도 : 22.333333333333332
# 폭력 등급이 10 인 격자의 평균 횡단보도 : 13.333333333333334
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 유소년인구 : 10.557476231633535
# 폭력 등급이 1 인 격자의 평균 유소년인구 : 41.38343558282209
# 폭력 등급이 2 인 격자의 평균 유소년인구 : 73.69642857142857
# 폭력 등급이 3 인 격자의 평균 유소년인구 : 105.01315789473684
# 폭력 등급이 4 인 격자의 평균 유소년인구 : 66.8984375
# 폭력 등급이 5 인 격자의 평균 유소년인구 : 100.12658227848101
# 폭력 등급이 6 인 격자의 평균 유소년인구 : 117.11111111111111
# 폭력 등급이 7 인 격자의 평균 유소년인구 : 103.4
# 폭력 등급이 8 인 격자의 평균 유소년인구 : 113.4
# 폭력 등급이 9 인 격자의 평균 유소년인구 : 54.666666666666664
# 폭력 등급이 10 인 격자의 평균 유소년인구 : 25.333333333333332
# ------------------------------------------------
# 폭력 등급이 0 인 격자의 평균 고령인구 : 9.855661192739845
# 폭력 등급이 1 인 격자의 평균 고령인구 : 58.89877300613497
# 폭력 등급이 2 인 격자의 평균 고령인구 : 145.19642857142858
# 폭력 등급이 3 인 격자의 평균 고령인구 : 155.56578947368422
# 폭력 등급이 4 인 격자의 평균 고령인구 : 117.15625
# 폭력 등급이 5 인 격자의 평균 고령인구 : 138.9367088607595
# 폭력 등급이 6 인 격자의 평균 고령인구 : 160.77777777777777
# 폭력 등급이 7 인 격자의 평균 고령인구 : 263.48
# 폭력 등급이 8 인 격자의 평균 고령인구 : 117.4
# 폭력 등급이 9 인 격자의 평균 고령인구 : 89.66666666666667
# 폭력 등급이 10 인 격자의 평균 고령인구 : 89.33333333333333
# ------------------------------------------------

# %%
new_grid['폭력빈도_4'] = 0

# %%
new_grid.loc[(new_grid['GRADE_폭력']==0),'폭력빈도_4'] = 0
new_grid.loc[(new_grid['GRADE_폭력']>0)&(new_grid['GRADE_폭력']<4),'폭력빈도_4'] = 1
new_grid.loc[(new_grid['GRADE_폭력']>=4)&(new_grid['GRADE_폭력']<8),'폭력빈도_4'] = 2
new_grid.loc[(new_grid['GRADE_폭력']>=8)&(new_grid['GRADE_폭력']<11),'폭력빈도_4'] = 3

# %%
scaler = StandardScaler()
new_grid[numerical_feats] = scaler.fit_transform(new_grid[numerical_feats])

# %%
feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력','폭력빈도_4']).columns)
feature = new_grid[feature_list]
target = new_grid[['폭력빈도_4']]

# %%
print(len(new_grid[new_grid['폭력빈도_4']==3]),len(new_grid[new_grid['GRADE_폭력']==8]),len(new_grid[new_grid['GRADE_폭력']==9]),len(new_grid[new_grid['GRADE_폭력']==10]))
# Out:
# 14 5 3 6

# %%
new_grid['GRADE_폭력'].value_counts()
# Out:
# 0     1157
# 1      326
# 3      152
# 4      128
# 2      112
# 5       79
# 6       45
# 7       25
# 10       6
# 8        5
# 9        3
# Name: GRADE_폭력, dtype: int64

# %%
new_grid['폭력빈도_4'].value_counts()
# Out:
# 0    1157
# 1     590
# 2     277
# 3      14
# Name: 폭력빈도_4, dtype: int64

# %%
model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
model.fit(X=feature, y=target) # 학습수행 
y_pred = model.predict(X = feature)
acc=accuracy_score(target,y_pred)
print('accuracy =', acc) 
con_mat = confusion_matrix(y_true=target, y_pred=y_pred) 
con_mat
# Out:
# accuracy = 0.774288518155054
# array([[1104,   51,    2,    0],
#        [ 215,  322,   53,    0],
#        [  25,  111,  140,    1],
#        [   0,    1,    1,   12]])

# %%
from sklearn.metrics import classification_report
model.fit(X=feature, y=target) # 학습수행 
y_pred = model.predict(X = feature)
print(classification_report(target, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88      1157
#            1       0.66      0.55      0.60       590
#            2       0.71      0.51      0.59       277
#            3       0.92      0.86      0.89        14
#
#     accuracy                           0.77      2038
#    macro avg       0.78      0.72      0.74      2038
# weighted avg       0.76      0.77      0.76      2038

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력','폭력빈도_4']).columns)
    feature = df_train[feature_list]
    target = df_train[['폭력빈도_4']]
    
    
    model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(target,y_pred1)
    acc_2=accuracy_score(df_test['폭력빈도_4'],y_pred2)
    
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 0.77239264, 검증 Accuracy = 0.76470588
# 학습 Accuracy = 0.78773006, 검증 Accuracy = 0.73039216
# 학습 Accuracy = 0.76809816, 검증 Accuracy = 0.77205882
# 학습 Accuracy = 0.77437155, 검증 Accuracy = 0.74692875
# 학습 Accuracy = 0.77314531, 검증 Accuracy = 0.73710074
# [0.76470588 0.73039216 0.77205882 0.74692875 0.73710074]
# 0.7502372693549164

# %%
plt.figure(figsize=(20,20)) # chart size 
sns.heatmap(con_mat, annot=True, fmt=".3f", linewidths=.5, square = True);# , cmap = 'Blues_r' : map »ö»ó  
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Accuracy Score: {0}'.format(acc) 
plt.title(all_sample_title, size = 18) 
plt.show()

# %%
new_grid['폭력빈도_3'] = 0

# %%
#new_grid.loc[(new_grid['GRADE_폭력']==0),'폭력빈도'] = 0
new_grid.loc[(new_grid['GRADE_폭력']>=0)&(new_grid['GRADE_폭력']<4),'폭력빈도_3'] = 1
new_grid.loc[(new_grid['GRADE_폭력']>=4)&(new_grid['GRADE_폭력']<8),'폭력빈도_3'] = 2
new_grid.loc[(new_grid['GRADE_폭력']>=8)&(new_grid['GRADE_폭력']<11),'폭력빈도_3'] = 3

# %%
new_grid['폭력빈도_3'].value_counts()
# Out:
# 1    1747
# 2     277
# 3      14
# Name: 폭력빈도_3, dtype: int64

# %%
feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력','폭력빈도_3','폭력빈도_4']).columns)
feature = new_grid[feature_list]
target = new_grid[['폭력빈도_3']]

# %%
model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
model.fit(X=feature, y=target) # 학습수행 
y_pred = model.predict(X = feature)
acc=accuracy_score(target,y_pred)
print('accuracy =', acc) 
con_mat = confusion_matrix(y_true=target, y_pred=y_pred) 
con_mat
# Out:
# accuracy = 0.8974484789008832
# array([[1683,   64,    0],
#        [ 142,  134,    1],
#        [   1,    1,   12]])

# %%
from sklearn.metrics import classification_report
model.fit(X=feature, y=target) # 학습수행 
y_pred = model.predict(X = feature)
print(classification_report(target, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.96      0.94      1747
#            2       0.67      0.48      0.56       277
#            3       0.92      0.86      0.89        14
#
#     accuracy                           0.90      2038
#    macro avg       0.84      0.77      0.80      2038
# weighted avg       0.89      0.90      0.89      2038

# %%
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(new_grid)):
    df_train = new_grid.iloc[idx_train]
    df_test = new_grid.iloc[idx_test]
    feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력','폭력빈도_4','폭력빈도_3']).columns)
    feature = df_train[feature_list]
    target = df_train[['폭력빈도_3']]
    
    
    model = LogisticRegression(random_state=0, solver ='lbfgs', multi_class='multinomial')
    model.fit(X=feature, y=target) # 학습수행 
    y_pred1 = model.predict(X = feature)
    y_pred2 = model.predict(X = df_test[feature_list])
    acc_1=accuracy_score(target,y_pred1)
    acc_2=accuracy_score(df_test['폭력빈도_3'],y_pred2)
    
    scores[i] = acc_2
    print("학습 Accuracy = {:.8f}, 검증 Accuracy = {:.8f}".format(acc_1, acc_2))
print(scores)
scores.mean()
# Out:
# 학습 Accuracy = 0.89754601, 검증 Accuracy = 0.89215686
# 학습 Accuracy = 0.90552147, 검증 Accuracy = 0.87745098
# 학습 Accuracy = 0.89570552, 검증 Accuracy = 0.88970588
# 학습 Accuracy = 0.90067443, 검증 Accuracy = 0.89189189
# 학습 Accuracy = 0.90128755, 검증 Accuracy = 0.89189189
# [0.89215686 0.87745098 0.88970588 0.89189189 0.89189189]
# 0.888619501854796

# %%
plt.figure(figsize=(20,20)) # chart size 
sns.heatmap(con_mat, annot=True, fmt=".3f", linewidths=.5, square = True);# , cmap = 'Blues_r' : map »ö»ó  
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Accuracy Score: {0}'.format(acc) 
plt.title(all_sample_title, size = 18) 
plt.show()

# %%
new_grid.columns
# Out:
# Index(['ID', '총인구', '유소년인구', '고령인구', '건축물(30_34)', '건축물(35)', '개별주택가격', '공시지가',
#        '행정동코드', '가로등', '공영주차장', '공중화장실', '교육시설', '대규모점포', '대부업현황', '룸살롱',
#        '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집', '오락시설', '원룸_오피스텔',
#        '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도', 'GRADE_폭력', 'GRADE_절도',
#        'GRADE_성폭력', '성폭력취약인구', '건축물(30_)', '폭력빈도_4', '폭력빈도_3'],
#       dtype='object')

# %%
py_data = feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력','폭력빈도_3']).columns)
feature = new_grid[feature_list]

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = feature,
            train_size = 0.7,
            target = '폭력빈도_4',
            use_gpu = False, 
            session_id = 2021,
           fold_shuffle = True)
# Out:
# <style  type="text/css" >
# #T_faa82088_01d3_11ec_a03e_acbc32d61fabrow44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_faa82088_01d3_11ec_a03e_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow0_col1" class="data row0 col1" >2021</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow1_col1" class="data row1 col1" >폭력빈도_4</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow3_col1" class="data row3 col1" >0: 0, 1: 1, 2: 2, 3: 3</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow4_col1" class="data row4 col1" >(2038, 32)</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow6_col1" class="data row6 col1" >29</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow11_col1" class="data row11 col1" >(1426, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow12_col1" class="data row12 col1" >(612, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_faa82088_01d3_11ec_a03e_acbc32d61fablevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_faa82088_01d3_11ec_a03e_acbc32d61fabrow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_faa82088_01d3_11ec_a

# %%
best_5 = compare_models(sort = 'Accuracy', n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_40decc32_01d4_11ec_a03e_acbc32d61fab th {
#           text-align: left;
#     }#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col0,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col3,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col7,#T_40decc32_01d4_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col1,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col2,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col4,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col5,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col6,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col7,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow0_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow1_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow2_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow3_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow4_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow5_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow6_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow8_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow9_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow10_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow11_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow12_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow13_col8,#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_40decc32_01d4_11ec_a03e_acbc32d61fabrow7_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_40decc32_01d4_11ec_a03e_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40decc32_01d4_11ec_a03e_acbc32d61fablevel0_row0" class="row_heading level0 row0" >rf</th>

# %%
blended = blend_models(estimator_list = best_5, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col0,#T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col1,#T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col2,#T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col3,#T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col4,#T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col5,#T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col6{
#             background:  yellow;
#         }</style><table id="T_57592a7a_01d4_11ec_a03e_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col0" class="data row0 col0" >0.7692</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col1" class="data row0 col1" >0.8904</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col2" class="data row0 col2" >0.6338</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col3" class="data row0 col3" >0.7579</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col4" class="data row0 col4" >0.7568</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col5" class="data row0 col5" >0.5674</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow0_col6" class="data row0 col6" >0.5758</td>
#             </tr>
#             <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col0" class="data row1 col0" >0.7789</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col1" class="data row1 col1" >0.8998</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col2" class="data row1 col2" >0.5157</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col3" class="data row1 col3" >0.7740</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col4" class="data row1 col4" >0.7752</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col5" class="data row1 col5" >0.6003</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow1_col6" class="data row1 col6" >0.6014</td>
#             </tr>
#             <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col0" class="data row2 col0" >0.7825</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col1" class="data row2 col1" >0.8595</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col2" class="data row2 col2" >0.7386</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col3" class="data row2 col3" >0.7670</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col4" class="data row2 col4" >0.7682</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col5" class="data row2 col5" >0.5925</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow2_col6" class="data row2 col6" >0.5995</td>
#             </tr>
#             <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col0" class="data row3 col0" >0.7754</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col1" class="data row3 col1" >0.8918</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col2" class="data row3 col2" >0.4973</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col3" class="data row3 col3" >0.7576</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col4" class="data row3 col4" >0.7646</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col5" class="data row3 col5" >0.5864</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow3_col6" class="data row3 col6" >0.5891</td>
#             </tr>
#             <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col0" class="data row4 col0" >0.8105</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col1" class="data row4 col1" >0.9082</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col2" class="data row4 col2" >0.5157</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col3" class="data row4 col3" >0.7955</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col4" class="data row4 col4" >0.7975</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col5" class="data row4 col5" >0.6492</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow4_col6" class="data row4 col6" >0.6531</td>
#             </tr>
#             <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col0" class="data row5 col0" >0.7833</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col1" class="data row5 col1" >0.8899</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col2" class="data row5 col2" >0.5802</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col3" class="data row5 col3" >0.7704</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col4" class="data row5 col4" >0.7725</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col5" class="data row5 col5" >0.5992</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow5_col6" class="data row5 col6" >0.6038</td>
#             </tr>
#             <tr>
#                         <th id="T_57592a7a_01d4_11ec_a03e_acbc32d61fablevel0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col0" class="data row6 col0" >0.0143</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col1" class="data row6 col1" >0.0165</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col2" class="data row6 col2" >0.0929</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col3" class="data row6 col3" >0.0140</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col4" class="data row6 col4" >0.0139</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col5" class="data row6 col5" >0.0273</td>
#                         <td id="T_57592a7a_01d4_11ec_a03e_acbc32d61fabrow6_col6" class="data row6 col6" >0.0263</td>
#             </tr>
#     </tbody></table>

# %%
py_data = feature_list = list(new_grid.drop(columns = ['행정동코드','ID','GRADE_절도','GRADE_성폭력','GRADE_폭력','폭력빈도_4']).columns)
feature = new_grid[feature_list]

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = feature,
            train_size = 0.7,
            target = '폭력빈도_3',
            use_gpu = False, 
            session_id = 2021,
           fold_shuffle = True)
# Out:
# <style  type="text/css" >
# #T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow0_col1" class="data row0 col1" >2021</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow1_col1" class="data row1 col1" >폭력빈도_3</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow4_col1" class="data row4 col1" >(2038, 32)</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow6_col1" class="data row6 col1" >29</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow11_col1" class="data row11 col1" >(1426, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow12_col1" class="data row12 col1" >(612, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fablevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_acbc32d61fabrow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_58c90e8e_01d4_11ec_a03e_ac

# %%
best_5 = compare_models(sort = 'Accuracy', n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_9ba17cf0_01d4_11ec_a03e_acbc32d61fab th {
#           text-align: left;
#     }#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col0,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col3,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col7,#T_9ba17cf0_01d4_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col1,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col2,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col4,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col5,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col6,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col7,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow1_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow2_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow3_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow4_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow5_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow6_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow8_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow9_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow10_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow11_col8,#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow7_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fablevel0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col1" class="data row0 col1" >0.8983</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col2" class="data row0 col2" >0.7457</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col3" class="data row0 col3" >0.5123</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col4" class="data row0 col4" >0.8403</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col5" class="data row0 col5" >0.8146</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d61fabrow0_col6" class="data row0 col6" >0.5089</td>
#                         <td id="T_9ba17cf0_01d4_11ec_a03e_acbc32d

# %%
blended = blend_models(estimator_list = best_5, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col0,#T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col1,#T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col2,#T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col3,#T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col4,#T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col5,#T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col6{
#             background:  yellow;
#         }</style><table id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col0" class="data row0 col0" >0.9021</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col1" class="data row0 col1" >0.9505</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col2" class="data row0 col2" >0.5051</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col3" class="data row0 col3" >0.8912</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col4" class="data row0 col4" >0.8963</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col5" class="data row0 col5" >0.5463</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow0_col6" class="data row0 col6" >0.5489</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col0" class="data row1 col0" >0.8526</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col1" class="data row1 col1" >0.8882</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col2" class="data row1 col2" >0.4275</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col3" class="data row1 col3" >0.8392</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col4" class="data row1 col4" >0.8454</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col5" class="data row1 col5" >0.3097</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow1_col6" class="data row1 col6" >0.3117</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col0" class="data row2 col0" >0.8947</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col1" class="data row2 col1" >0.9116</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col2" class="data row2 col2" >0.4897</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col3" class="data row2 col3" >0.8848</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col4" class="data row2 col4" >0.8890</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col5" class="data row2 col5" >0.5069</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow2_col6" class="data row2 col6" >0.5102</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col0" class="data row3 col0" >0.8807</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col1" class="data row3 col1" >0.8699</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col2" class="data row3 col2" >0.6148</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col3" class="data row3 col3" >0.8678</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col4" class="data row3 col4" >0.8718</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col5" class="data row3 col5" >0.4149</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow3_col6" class="data row3 col6" >0.4225</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col0" class="data row4 col0" >0.8982</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col1" class="data row4 col1" >0.9432</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col2" class="data row4 col2" >0.4720</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col3" class="data row4 col3" >0.8808</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col4" class="data row4 col4" >0.8868</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col5" class="data row4 col5" >0.4868</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow4_col6" class="data row4 col6" >0.5000</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col0" class="data row5 col0" >0.8857</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col1" class="data row5 col1" >0.9127</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col2" class="data row5 col2" >0.5018</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col3" class="data row5 col3" >0.8728</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col4" class="data row5 col4" >0.8778</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col5" class="data row5 col5" >0.4529</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow5_col6" class="data row5 col6" >0.4586</td>
#             </tr>
#             <tr>
#                         <th id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fablevel0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col0" class="data row6 col0" >0.0180</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col1" class="data row6 col1" >0.0310</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col2" class="data row6 col2" >0.0622</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col3" class="data row6 col3" >0.0184</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col4" class="data row6 col4" >0.0181</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col5" class="data row6 col5" >0.0834</td>
#                         <td id="T_b3ec8de0_01d4_11ec_a03e_acbc32d61fabrow6_col6" class="data row6 col6" >0.0841</td>
#             </tr>
#     </tbody></table>
