# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib 
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

from sklearn.ensemble import RandomForestRegressor

from statsmodels.stats.outliers_influence import variance_inflation_factor
from pycaret.regression import *
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
import pandas_profiling
import statsmodels.api as sm
from sklearn.decomposition import PCA

# %%
grid_500 = pd.read_csv('/Users/gimdong-wan/Desktop/DataCampus/data/final_data/500grid_data.csv')

# %% [markdown]
# ### 자료 소개
#
# **`grid_500_data.csv`는 전주시를 500x500격자로 나눈 후 인구와 공간적 데이터, 그리고 범죄주의구간(폭행, 절도, 성폭행) 등급의 강도로 구성되어있다.
# 해당 데이터를 통해 전주시의 3대 범죄 발생에 영향을 끼치는 요인을 파악 후 범죄 위험지역에 대해 판단해 보려한다.**
#
# **데이터는 국가정보포털에서 격자별 인구 및 건축물에 대한 데이터를 수집하였으며, 가로등 주차장 등은 각 데이터의 좌표를 기준으로 격자내의 개수를 입력하였다.**
# **범죄주의구간은 생활안전지도의 치안사고발생현황을 바탕으로 만들어진 범죄주의구간 (1~10등급)의 지도를 이용하여 격자별 주의구간의 등급을 산정했다. (각 등급의 최대값)**
# 자료는 총 43개의 변수로 구성되어 있으며, 격자는 총 918개이다.
#
# #### raw data
# <code>gird_500</code> = 전주시 범죄관련 데이터
# - <code>INDEX</code> = 인덱스
# - <code>ID</code> = 각 격자의 고유 ID
# - <code>총인구</code> = 격자별 총인구
# - <code>남성인구</code> = 격자별 남성인구
# - <code>여성인구</code> = 격자별 여성인구
# - <code>고등여성인구</code> = 격자별 고등학생 여성인구(이 변수는 성폭력 취약인구에 포함)
# - <code>20대여성인구</code> = 격자별 20대 여성인구(이 변수는 성폭력 취약인구에 포함)
# - <code>유소년인구</code> = 격자별 유소년인구(0~14세)
# - <code>고령인구</code> = 격자별 고령인구(65세 이상)
# - <code>30년이상35년미만건축물</code> = 30년이상 35년미만건축물의 수
# - <code>35년이상건축물</code> = 35년이상 건축물
# - <code>개별주택가격</code> = 격자별 개별주택가격의 평균
# - <code>공시지가</code> = 격자별 평균 공시지가
# - <code>행정동코드</code> = 격자가 속한 행정동
# - <code>가로등</code> = 격자별 가로등의 수
# - <code>공영주차장</code> = 격자별 공영주차장수
# - <code>공중화장실</code> = 격자별 공중화장실수
# - <code>교육시설</code> = 격자별 교육시설의 수 (학원, 어린이집)
# - <code>교통사고_19</code> = 격자별 2019년 교통사고 발생건수
# - <code>교통사고_20</code> = 격자별 2020년 교통사고 발생건수
# - <code>노숙인시설</code> = 격자별 노숙인시설의 수
# - <code>대규모점포</code> = 격자별 대규모 점포의 수 (홈플러스, 이마트 등)
# - <code>대부업현황</code> = 격자별 대부업체의 수
# - <code>룸살롱</code> = 격자별 룸살롱의 수
# - <code>버스정류장</code> = 격자별 버스정류장의 수
# - <code>보안등</code> = 격자별 보안등의 수
# - <code>상가</code> = 격자별 상가의 수 (교육시설,음식점,술집,도소매업 오락시설을 포함한 상가의 수)
# - <code>숙박업소</code> = 격자별 숙박업소의 수
# - <code>술집</code> = 격자별 술집 (술집+룸살롱)
# - <code>어린이보호</code> = 격자별 어린이보호구역의 수
# - <code>어린이집</code> = 격자별 어린이집 수
# - <code>오락시설</code> = 격자별 오락시설 (노래방, 당구장, pc방 등)
# - <code>원룸_오피스텔</code> = 격자별 원룸 및 오피스텔의 수
# - <code>유흥시설</code> = 격자별 유흥시설 (술집, 오락시설, 음식점)
# - <code>음식점</code> = 격자별 음식점 수
# - <code>자율방범대</code> = 격자별 자율방범대 수
# - <code>파출소</code> = 격자별 파출소의 수
# - <code>cctv</code> = 격자별 cctv 수
# - <code>신호등</code> = 격자별 신호등의 수
# - <code>횡단보도</code> = 격자별 횡단보도의 수
# - <code>GRADE_폭력</code> = 격자별 폭력주의등급(2~11)
# - <code>GRADE_절도</code> = 격자별 절도주의등급(2~11)
# - <code>GRADE_성폭력</code> = 격자별 성폭력주의등급(2~11)

# %%
len(grid_500.columns)
# Out:
# 43

# %%
len(grid_500)
# Out:
# 918

# %%
grid_500.dtypes
# Out:
# INDEX              int64
# ID                object
# 총인구                int64
# 남성인구               int64
# 여성인구               int64
# 고등여성인구             int64
# 20대여성인구            int64
# 유소년인구              int64
# 고령인구               int64
# 30년이상35년미만건축물      int64
# 35년이상건축물           int64
# 개별주택가격           float64
# 공시지가             float64
# 행정동코드             object
# 가로등                int64
# 공영주차장              int64
# 공중화장실              int64
# 교육시설               int64
# 교통사고_19            int64
# 교통사고_20            int64
# 노숙인시설              int64
# 대규모점포              int64
# 대부업현황              int64
# 룸살롱                int64
# 버스정류장              int64
# 보안등                int64
# 상가                 int64
# 숙박업소               int64
# 술집                 int64
# 어린이보호              int64
# 어린이집               int64
# 오락시설               int64
# 원룸_오피스텔            int64
# 유흥시설               int64
# 음식점                int64
# 자율방범대              int64
# 파출소                int64
# cctv               int64
# 신호등                int64
# 횡단보도               int64
# GRADE_폭력           int64
# GRADE_절도           int64
# GRADE_성폭력          int64
# dtype: object

# %%
grid_500.head(3)
# Out:
#    INDEX        ID   총인구  남성인구  여성인구  고등여성인구  20대여성인구  유소년인구  고령인구  \
# 0      0  다마66a58a  1758   829   929      37      114    173   282
# 1      1  다마68a60b  2551  1281  1270      37      170    218   643
# 2      2  다마69b61b   169    87    82       0        0      0    75
#
#    30년이상35년미만건축물  35년이상건축물        개별주택가격       공시지가  행정동코드  가로등  공영주차장  공중화장실  \
# 0              0         3  1.784059e+08  162445.31  중화산2동    8      1      4
# 1             81       381  9.432807e+07  429815.61   인후2동   30      0      2
# 2              7        27  7.005660e+07  106154.66   우아1동    0      0      0
#
#    교육시설  교통사고_19  교통사고_20  노숙인시설  대규모점포  대부업현황  룸살롱  버스정류장  보안등  상가  숙박업소  술집  \
# 0    10        9        4      0      0      0    0      0   22  30     0   1
# 1     4        6       13      0      0      0    0      1    7  92     0   2
# 2     0        0        0      0      0      0    0      0    2  17     0   0
#
#    어린이보호  어린이집  오락시설  원룸_오피스텔  유흥시설  음식점  자율방범대  파출소  cctv  신호등  횡단보도  \
# 0      0     2     0       12    10   10      0    0     3    0     1
# 1      3     2     3       69    26   23      1    0    11    7    45
# 2      0     0     0        1    10   10      0    0     1    0     0
#
#    GRADE_폭력  GRADE_절도  GRADE_성폭력
# 0         5         3          0
# 1         6         5          3
# 2         2         3          0

# %%
grid_500['성폭력취약인구'] = grid_500['고등여성인구']+grid_500['20대여성인구']
grid_500['GRADE_폭력'] = grid_500['GRADE_폭력'].apply(lambda x: x-1 if x>0 else x)
grid_500['GRADE_절도'] = grid_500['GRADE_절도'].apply(lambda x: x-1 if x>0 else x)
grid_500['GRADE_성폭력'] = grid_500['GRADE_성폭력'].apply(lambda x: x-1 if x>0 else x)

# %% [markdown]
# ### 데이터 처리
#    - 성폭력 취약인구 = 고등여성인구 + 20대여성인구
#         - 통계에 의하면 2018년도 강간 피해자 성별이 여성인 경우는 강간범죄(유사강간 포함) 총 6069건 중 96.8%, 강제추행범죄 총 17053건 중 89.2%를 차지하고 있다. 여성 피해자 중 21-30세가 33.7%(1981명), 31-40세가 13.7%였다. 주목할 점은 연령 구분이 10년 간격으로 나눠지지 않는 연령대인 16-20세가 21.8%(1281명)로 20대에 이어 두 번째로 많다.
#    - GIS에서 생활안전지도를 불러온 결과 1-10등급의 구분이 2-11로 되어있으므로 apply를 이용해 0보다 크다면 각 1씩 빼주어 등급을 1~10으로 재조정하였음
#    - 유소년, 고령, 성폭력취약 인구를 비율로 이용할지 수치로 이용할지는 .. 검토해봐야할듯

# %%
grid_500.describe()
# Out:
#             INDEX          총인구         남성인구         여성인구      고등여성인구  \
# count  918.000000   918.000000   918.000000   918.000000  918.000000
# mean   458.500000   714.693900   351.464052   362.875817   10.930283
# std    265.148072  1532.693288   746.379116   787.240988   27.950095
# min      0.000000     0.000000     0.000000     0.000000    0.000000
# 25%    229.250000     0.000000     0.000000     0.000000    0.000000
# 50%    458.500000    24.000000    13.000000    11.500000    0.000000
# 75%    687.750000   291.000000   153.750000   137.500000    0.000000
# max    917.000000  8753.000000  4173.000000  4580.000000  186.000000
#
#           20대여성인구        유소년인구         고령인구  30년이상35년미만건축물    35년이상건축물  \
# count  918.000000   918.000000   918.000000     918.000000  918.000000
# mean    46.836601    82.391068   122.736383       5.587146   24.537037
# std    106.057666   215.078664   260.815712      23.184117   77.426084
# min      0.000000     0.000000     0.000000       0.000000    0.000000
# 25%      0.000000     0.000000     0.000000       0.000000    0.000000
# 50%      0.000000     0.000000     8.000000       0.000000    1.000000
# 75%     16.000000    21.000000    58.000000       1.000000    8.000000
# max    649.000000  1996.000000  1573.000000     402.000000  682.000000
#
#              개별주택가격          공시지가         가로등       공영주차장       공중화장실  \
# count  9.180000e+02  9.180000e+02  918.000000  918.000000  918.000000
# mean   8.729869e+07  1.898196e+05   16.093682    0.087146    0.352941
# std    1.060985e+08  2.976483e+05   30.342177    0.411169    1.039906
# min    0.000000e+00  0.000000e+00    0.000000    0.000000    0.000000
# 25%    0.000000e+00  1.256998e+04    0.000000    0.000000    0.000000
# 50%    6.405639e+07  5.336395e+04    0.000000    0.000000    0.000000
# 75%    1.220900e+08  2.356136e+05   20.750000    0.000000    0.000000
# max    5.610000e+08  2.312433e+06  196.000000    6.000000   10.000000
#
#              교육시설     교통사고_19     교통사고_20       노숙인시설       대규모점포       대부업현황  \
# count  918.000000  918.000000  918.000000  918.000000  918.000000  918.000000
# mean     4.028322    2.983660    2.469499    0.003268    0.041394    0.094771
# std     12.948150    5.882599    9.154237    0.057104    0.273168    0.402764
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000    0.000000    0.000000    0.000000
# max    126.000000   43.000000  128.000000    1.000000    4.000000    4.000000
#
#               룸살롱       버스정류장         보안등           상가        숙박업소  \
# count  918.000000  918.000000  918.000000   918.000000  918.000000
# mean     0.299564    0.619826   11.122004    36.741830    0.449891
# std      2.587323    1.345585   27.225147    90.192462    2.628423
# min      0.000000    0.000000    0.000000     0.000000    0.000000
# 25%      0.000000    0.000000    0.000000     0.000000    0.000000
# 50%      0.000000    0.000000    0.000000     1.000000    0.000000
# 75%      0.000000    0.750000    7.000000    17.000000    0.000000
# max     43.000000   11.000000  196.000000  1114.000000   28.000000
#
#                술집       어린이보호       어린이집        오락시설     원룸_오피스텔        유흥시설  \
# count  918.000000  918.000000  918.00000  918.000000  918.000000  918.000000
# mean     1.545752    0.267974    0.66122    0.899782    9.514161   13.901961
# std      5.550755    0.717501    1.99280    3.132616   30.737239   36.834671
# min      0.000000    0.000000    0.00000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.00000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.00000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.00000    0.000000    1.000000    5.000000
# max     77.000000    6.000000   25.00000   40.000000  288.000000  354.000000
#
#               음식점       자율방범대         파출소        cctv         신호등        횡단보도  \
# count  918.000000  918.000000  918.000000  918.000000  918.000000  918.000000
# mean    13.002179    0.052288    0.020697    1.464052    4.141612    7.485839
# std     34.119266    0.241520    0.142446    2.832725    8.246316   15.055742
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      5.000000    0.000000    0.000000    1.000000    4.000000    8.000000
# max    328.000000    2.000000    1.000000   14.000000   54.000000  146.000000
#
#          GRADE_폭력    GRADE_절도   GRADE_성폭력     성폭력취약인구
# count  918.000000  918.000000  918.000000  918.000000
# mean     1.172113    1.425926    0.614379   57.766885
# std      2.041768    2.332377    1.592475  132.421282
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    2.000000    0.000000   16.750000
# max     10.000000   10.000000   10.000000  815.000000

# %%
grid_500.isna().sum()
# Out:
# INDEX            0
# ID               0
# 총인구              0
# 남성인구             0
# 여성인구             0
# 고등여성인구           0
# 20대여성인구          0
# 유소년인구            0
# 고령인구             0
# 30년이상35년미만건축물    0
# 35년이상건축물         0
# 개별주택가격           0
# 공시지가             0
# 행정동코드            0
# 가로등              0
# 공영주차장            0
# 공중화장실            0
# 교육시설             0
# 교통사고_19          0
# 교통사고_20          0
# 노숙인시설            0
# 대규모점포            0
# 대부업현황            0
# 룸살롱              0
# 버스정류장            0
# 보안등              0
# 상가               0
# 숙박업소             0
# 술집               0
# 어린이보호            0
# 어린이집             0
# 오락시설             0
# 원룸_오피스텔          0
# 유흥시설             0
# 음식점              0
# 자율방범대            0
# 파출소              0
# cctv             0
# 신호등              0
# 횡단보도             0
# GRADE_폭력         0
# GRADE_절도         0
# GRADE_성폭력        0
# 성폭력취약인구          0
# dtype: int64

# %%
grid_500.corr()
# Out:
#                   INDEX       총인구      남성인구      여성인구    고등여성인구   20대여성인구  \
# 숙박업소           0.275696  0.187138  0.359574  0.368999  0.341020   0.431250
# 술집             0.533926  0.346262  0.524133  0.622820  0.563651   0.574554
# 어린이보호          0.580454  0.414174  0.440292  0.466481  0.449778   0.359682
# 어린이집           0.488228  0.452313  0.428276  0.498651  0.509472   0.371148
# 오락시설           0.519913  0.394751  0.555078  0.605748  0.596744   0.526067
# 원룸_오피스텔        0.633089  0.382273  0.474542  0.487195  0.478228   0.407570
# 유흥시설           0.625569  0.513162  0.673597  0.695818  0.715146   0.644497
# 음식점            0.627620  0.517759  0.676242  0.695579  0.717272   0.647490
# 자율방범대          0.480934  0.209820  0.287508  0.357672  0.353407   0.310498
# 파출소            0.270751  0.190603  0.218022  0.250204  0.232741   0.198673
# cctv           1.000000  0.535775  0.660847  0.708876  0.707350   0.609017
# 신호등            0.535775  1.000000  0.761451  0.551545  0.614535   0.399028
# 횡단보도           0.660847  0.761451  1.000000  0.681589  0.710381   0.561769
# GRADE_폭력       0.708876  0.551545  0.681589  1.000000  0.816069   0.714359
# GRADE_절도       0.707350  0.614535  0.710381  0.816069  1.000000   0.676982
# GRADE_성폭력      0.609017  0.399028  0.561769  0.714359  0.676982   1.000000
# 성폭력취약인구        0.656730  0.625212  0.596235  0.668399  0.675582   0.546599
#
#                 성폭력취약인구
# INDEX         -0.252690
# 총인구            0.978368
# 남성인구           0.977634
# 여성인구           0.978108
# 고등여성인구         0.954879
# 20대여성인구        0.996932
# 유소년인구          0.881813
# 고령인구           0.817647
# 30년이상35년미만건축물  0.284297
# 35년이상건축물       0.205856
# 개별주택가격         0.537951
# 공시지가           0.643403
# 가로등            0.601231
# 공영주차장          0.280494
# 공중화장실          0.350158
# 교육시설           0.750706
# 교통사고_19        0.556243
# 교통사고_20        0.267647
# 노숙인시설          0.013945
# 대규모점포          0.262877
# 대부업현황          0.302350
# 룸살롱            0.113451
# 버스정류장          0.650661
# 보안등            0.301659
# 상가             0.624379
# 숙박업소           0.099196
# 술집             0.484514
# 어린이보호          0.532185
# 어린이집           0.780591
# 오락시설           0.518211
# 원룸_오피스텔        0.572463
# 유흥시설           0.613705
# 음식점            0.614968
# 자율방범대          0.273399
# 파출소            0.233703
# cctv           0.656730
# 신호등            0.625212
# 횡단보도           0.596235
# GRADE_폭력       0.668399
# GRADE_절도       0.675582
# GRADE_성폭력      0.546599
# 성폭력취약인구        1.000000

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(grid_500.corr(), annot=True)
plt.show()

# %% [markdown]
# ### 전체 변수 간 상관관계
#  - 인구 사회학적 변수는 변수간 상관관계가 크며, 이는 다중공선성 제거를 위해 변수를 선택할 필요가 있다. 또한, 대부분 범죄 등급과도 큰 상관관계를 보이고 있다.
#
# #### 종속변수 (3대범죄)를 기반으로 한 상관계수 확인
#  - 폭력
#      - `인구` : 총인구 (0.68), 남성인구(0.69), 여성인구(0.68), 성폭력취약인구(0.67), 유소년인구(0.51), 고령인구(0.7)
#      - `토지` : 30년 이상35년 미만 건축물(0.37), 35년 이상건축물(0.44), 개별주택가격 (0.51), 공시지가(0.64)
#      - `시설물` : 가로등(0.65), 공영주차장(0.38), 공중화장실(0.45), 교육시설(0.54), 노숙인시설(0.08), 대규모점포(0.24), 대부업체현황(0.39), 룸살롱(0.34), 버스정류장(0.63), 보안등(0.31), 상가(0.68), 숙박업소(0.37), 술집(0.62), 어린이보호구역(0.47), 어린이집(0.5), 오락시설(0.61), 원룸_오피스텔(0.49), 유흥시설(0.7), 음식점(0.7), 자율방범대(0.36), 파출소(0.25), cctv(0.71), 신호등(0.55), 횡단보도(0.68),
#      - `사고` : 교통사고_19(0.69), 교통사고_20(0.3)
#      - `다른 범죄` : 절도(0.82), 성폭력(0.71)
#  - 절도
#      - `인구` : 총인구 (0.68), 남성인구(0.69), 여성인구(0.68), 성폭력취약인구(0.68), 유소년인구(0.53), 고령인구(0.69)
#      - `토지` : 30년 이상35년 미만 건축물(0.34), 35년 이상건축물(0.43), 개별주택가격 (0.54), 공시지가(0.74)
#      - `시설물` : 가로등(0.7), 공영주차장(0.38), 공중화장실(0.46), 교육시설(0.57), 노숙인시설(0.05), 대규모점포(0.36), 대부업체현황(0.4), 룸살롱(0.25), 버스정류장(0.68), 보안등(0.43), 상가(0.73), 숙박업소(0.34), 술집(0.56), 어린이보호구역(0.45), 어린이집(0.51), 오락시설(0.6), 원룸_오피스텔(0.48), 유흥시설(0.72), 음식점(0.72), 자율방범대(0.35), 파출소(0.23), cctv(0.71), 신호등(0.61), 횡단보도(0.71),
#      - `사고` : 교통사고_19(0.71), 교통사고_20(0.32)
#      - `다른 범죄` : 폭력(0.82), 성폭력(0.68)
#
#  - 성폭력
#      - `인구` : 총인구 (0.54), 남성인구(0.55), 여성인구(0.54), 성폭력취약인구(0.55), 유소년인구(0.38), 고령인구(0.59)
#      - `토지` : 30년 이상35년 미만 건축물(0.35), 35년 이상건축물(0.4), 개별주택가격 (0.39), 공시지가(0.55)
#      - `시설물` : 가로등(0.54), 공영주차장(0.42), 공중화장실(0.44), 교육시설(0.45), 노숙인시설(-0.02), 대규모점포(0.24), 대부업체현황(0.39), 룸살롱(0.28), 버스정류장(0.53), 보안등(0.34), 상가(0.62), 숙박업소(0.43), 술집(0.57), 어린이보호구역(0.36), 어린이집(0.37), 오락시설(0.53), 원룸_오피스텔(0.41), 유흥시설(0.64), 음식점(0.65), 자율방범대(0.31), 파출소(0.2), cctv(0.61), 신호등(0.41), 횡단보도(0.56),
#      - `사고` : 교통사고_19(0.62), 교통사고_20(0.24)
#      - `다른 범죄` : 절도(0.71), 성폭력(0.68)

# %% [markdown]
# ### Profile_report

# %%
plt.subplot(231)
plt.hist(grid_500['총인구'])
plt.xlabel('총인구')

plt.subplot(232)
plt.hist(grid_500['남성인구'])
plt.xlabel('남성인구')

plt.subplot(233)
plt.hist(grid_500['여성인구'])
plt.xlabel('여성인구')

plt.subplot(234)
plt.hist(grid_500['유소년인구'])
plt.xlabel('유소년인구')

plt.subplot(235)
plt.hist(grid_500['고령인구'])
plt.xlabel('고령인구')

plt.subplot(236)
plt.hist(grid_500['성폭력취약인구'])
plt.xlabel('성폭력취약인구')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 전체적으로 0인 격자가 많고 standard-scale 필요해보임

# %%
plt.subplot(221)
plt.hist(grid_500['30년이상35년미만건축물'])
plt.xlabel('30년이상35년미만건축물')

plt.subplot(222)
plt.hist(grid_500['35년이상건축물'])
plt.xlabel('35년이상건축물')

plt.subplot(223)
plt.hist(grid_500['개별주택가격'])
plt.xlabel('개별주택가격')

plt.subplot(224)
plt.hist(grid_500['공시지가'])
plt.xlabel('공시지가')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 토지에 관련한 변수를 살펴본 결과에서도 노후 건축물의 경우 데이터의 대부분이 0의 값을 가지고 있음.
# #### 개별주택가격과 공시지가의 경우도 데이터 간 분포차이가 매우 커보임
# #### -> standard-scale 필요

# %%
plt.subplot(331)
plt.hist(grid_500['가로등'])
plt.xlabel('가로등')

plt.subplot(332)
plt.hist(grid_500['공영주차장'])
plt.xlabel('공영주차장')

plt.subplot(333)
plt.hist(grid_500['공중화장실'])
plt.xlabel('공중화장실')

plt.subplot(334)
plt.hist(grid_500['교육시설'])
plt.xlabel('교육시설')

plt.subplot(335)
plt.hist(grid_500['노숙인시설'])
plt.xlabel('노숙인시설')

plt.subplot(336)
plt.hist(grid_500['대규모점포'])
plt.xlabel('대규모점포')

plt.subplot(337)
plt.hist(grid_500['대부업현황'])
plt.xlabel('대부업현황')

plt.subplot(338)
plt.hist(grid_500['룸살롱'])
plt.xlabel('룸살롱')

plt.subplot(339)
plt.hist(grid_500['버스정류장'])
plt.xlabel('버스정류장')

plt.tight_layout()
plt.show()

# %%
plt.subplot(331)
plt.hist(grid_500['보안등'])
plt.xlabel('보안등')

plt.subplot(332)
plt.hist(grid_500['상가'])
plt.xlabel('상가')

plt.subplot(333)
plt.hist(grid_500['숙박업소'])
plt.xlabel('숙박업소')

plt.subplot(334)
plt.hist(grid_500['술집'])
plt.xlabel('술집')

plt.subplot(335)
plt.hist(grid_500['어린이보호'])
plt.xlabel('어린이보호')

plt.subplot(336)
plt.hist(grid_500['어린이집'])
plt.xlabel('어린이집')

plt.subplot(337)
plt.hist(grid_500['오락시설'])
plt.xlabel('오락시설')

plt.subplot(338)
plt.hist(grid_500['원룸_오피스텔'])
plt.xlabel('원룸_오피스텔')

plt.subplot(339)
plt.hist(grid_500['유흥시설'])
plt.xlabel('유흥시설')

plt.tight_layout()
plt.show()

# %%
plt.subplot(321)
plt.hist(grid_500['음식점'])
plt.xlabel('음식점')

plt.subplot(322)
plt.hist(grid_500['자율방범대'])
plt.xlabel('자율방범대')

plt.subplot(323)
plt.hist(grid_500['파출소'])
plt.xlabel('파출소')

plt.subplot(324)
plt.hist(grid_500['cctv'])
plt.xlabel('cctv')

plt.subplot(325)
plt.hist(grid_500['신호등'])
plt.xlabel('신호등')

plt.subplot(326)
plt.hist(grid_500['횡단보도'])
plt.xlabel('횡단보도')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 공간적 변수도 대부분 0인 격자가 대부분이며 표준화 작업이 필수일듯

# %%
plt.subplot(131)
plt.hist(grid_500['GRADE_폭력'])
plt.xlabel('GRADE_폭력')

plt.subplot(132)
plt.hist(grid_500['GRADE_절도'])
plt.xlabel('GRADE_절도')

plt.subplot(133)
plt.hist(grid_500['GRADE_성폭력'])
plt.xlabel('GRADE_성폭력')

plt.tight_layout()
plt.show()

# %%
len(grid_500)
# Out:
# 918

# %%
len(grid_500[grid_500['GRADE_폭력']>0])
# Out:
# 330

# %%
len(grid_500[grid_500['GRADE_절도']>0])
# Out:
# 317

# %%
len(grid_500[grid_500['GRADE_성폭력']>0])
# Out:
# 142

# %% [markdown]
# - 918개의 격자 중 범죄주의구간의 등급이 0보다 큰 곳은 각 범죄별로 폭력 330, 절도 317, 성폭력 142이다.
#      - 이를 어떻게 해석하고 이용해야할까?
#      - 빼고 t-test ..?

# %%
grid_500.dtypes
# Out:
# INDEX              int64
# ID                object
# 총인구                int64
# 남성인구               int64
# 여성인구               int64
# 고등여성인구             int64
# 20대여성인구            int64
# 유소년인구              int64
# 고령인구               int64
# 30년이상35년미만건축물      int64
# 35년이상건축물           int64
# 개별주택가격           float64
# 공시지가             float64
# 행정동코드             object
# 가로등                int64
# 공영주차장              int64
# 공중화장실              int64
# 교육시설               int64
# 교통사고_19            int64
# 교통사고_20            int64
# 노숙인시설              int64
# 대규모점포              int64
# 대부업현황              int64
# 룸살롱                int64
# 버스정류장              int64
# 보안등                int64
# 상가                 int64
# 숙박업소               int64
# 술집                 int64
# 어린이보호              int64
# 어린이집               int64
# 오락시설               int64
# 원룸_오피스텔            int64
# 유흥시설               int64
# 음식점                int64
# 자율방범대              int64
# 파출소                int64
# cctv               int64
# 신호등                int64
# 횡단보도               int64
# GRADE_폭력           int64
# GRADE_절도           int64
# GRADE_성폭력          int64
# 성폭력취약인구            int64
# dtype: object

# %%
len(grid_500.columns)
# Out:
# 44

# %% [markdown]
# #### 분석에 이용할 numeric 변수에 대해 다중공선성 확인 및 정규화 준비를 위해 변수 구분

# %%
numerical_feats = grid_500.dtypes[grid_500.dtypes != "object"].index.tolist()
numerical_feats.remove('INDEX')
print("Number of Numerical features: ", len(numerical_feats))

categorical_feats = grid_500.dtypes[grid_500.dtypes == "object"].index.tolist()
print("Number of Categorical features: ", len(categorical_feats))
# Out:
# Number of Numerical features:  41
# Number of Categorical features:  2

# %%
grid_500.columns
# Out:
# Index(['INDEX', 'ID', '총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
#        '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '행정동코드', '가로등',
#        '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
#        '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
#        '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
#        'GRADE_폭력', 'GRADE_절도', 'GRADE_성폭력', '성폭력취약인구'],
#       dtype='object')

# %% [markdown]
# ### 다중회귀분석 target <- GRADE_폭력

# %%
# 다중 선형회귀분석
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     81.29
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          3.92e-252
# Time:                        14:16:50   Log-Likelihood:                -1285.5
# No. Observations:                 918   AIC:                             2645.
# Df Residuals:                     881   BIC:                             2823.
# Df Model:                          36
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(grid_500[numerical_feats].values, i) for i in range(grid_500[numerical_feats].shape[1])]
vif["features"] = grid_500[numerical_feats].columns 
vif
# Out:
#       VIF Factor       features
# 0   1.319535e+06            총인구
# 1   3.140797e+05           남성인구
# 2   3.479911e+05           여성인구
# 3            inf         고등여성인구
# 4            inf        20대여성인구
# 5   9.151171e+01          유소년인구
# 6   9.308310e+01           고령인구
# 7   1.796116e+00  30년이상35년미만건축물
# 8   3.924222e+00       35년이상건축물
# 9   3.222986e+00         개별주택가격
# 10  8.194909e+00           공시지가
# 11  5.593349e+00            가로등
# 12  1.932099e+00          공영주차장
# 13  2.059001e+00          공중화장실
# 14  6.357832e+00           교육시설
# 15  5.380915e+00        교통사고_19
# 16  1.497520e+00        교통사고_20
# 17  1.076761e+00          노숙인시설
# 18  2.099999e+00          대규모점포
# 19  1.791365e+00          대부업현황
# 20  2.579261e+00            룸살롱
# 21  4.242372e+00          버스정류장
# 22  2.834528e+00            보안등
# 23  1.174175e+01             상가
# 24  2.603789e+00           숙박업소
# 25  1.226567e+01             술집
# 26  2.428445e+00          어린이보호
# 27  4.970283e+00           어린이집
# 28           inf           오락시설
# 29  4.183231e+00        원룸_오피스텔
# 30           inf           유흥시설
# 31           inf            음식점
# 32  1.744207e+00          자율방범대
# 33  1.388051e+00            파출소
# 34  8.154295e+00           cctv
# 35  6.011957e+00            신호등
# 36  5.351982e+00           횡단보도
# 37  7.310935e+00       GRADE_폭력
# 38  6.600518e+00       GRADE_절도
# 39  3.313693e+00      GRADE_성폭력
# 40           inf        성폭력취약인구

# %% [markdown]
# ### 다중공선성에 크게 영향을 미치는 변수 제거 후 재분석

# %%
# 다중 선형회귀분석
x_data = grid_500[['유소년인구','고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     86.27
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          6.63e-247
# Time:                        14:16:50   Log-Likelihood:                -1307.6
# No. Observations:                 918   AIC:                             2681.
# Df Residuals:                     885   BIC:                             2840.
# Df Model:                          32
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0716      0.047      1.512      0.131      -0.021       0.165
# 유소년인구             0.0002      0.000      0.495      0.621      -0.001       0.001
# 고령인구              0.0030      0.000      7.884      0.000       0.002       0.004
# 30년이상35년미만건축물    -0.0023      0.002     -1.244      0.214      -0.006       0.001
# 35년이상건축물          0.0023      0.001      2.953      0.003       0.001       0.004
# 개별주택가격         3.385e-09   4.58e-10      7.391      0.000    2.49e-09    4.28e-09
# 공시지가           2.139e-07   2.76e-07      0.775      0.439   -3.28e-07    7.55e-07
# 가로등               0.0067      0.002      2.943      0.003       0.002       0.011
# 공영주차장             0.1194      0.109      1.093      0.275      -0.095       0.334
# 공중화장실             0.0631      0.044      1.436      0.151      -0.023       0.149
# 교육시설             -0.0029      0.006     -0.484      0.629      -0.015       0.009
# 교통사고_19           0.0404      0.012      3.439      0.001       0.017       0.064
# 교통사고_20          -0.0099      0.004     -2.275      0.023      -0.018      -0.001
# 노숙인시설             1.7402      0.603      2.885      0.004       0.556       2.924
# 대규모점포            -0.4785      0.174     -2.747      0.006      -0.820      -0.137
# 대부업현황            -0.1115      0.108     -1.028      0.304      -0.324       0.101
+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 메모:
# [1] 표준 오차는 오차의 공분산 행렬이 올바르게 지정되었다고 가정합니다.
# [2] 조건 번호가 2.43e+09로 큽니다. 이것은 다음이 있음을 나타낼 수 있습니다.
# 강한 다중공선성 또는 기타 수치 문제.

# %% [markdown]
# ### Stepwise

# %%
# 변수선택을 통해 형성한 모델의 AIC를 구하는 함수
# AIC가 낮을 수록 모델이 좋다고 평가된다.
# 다중 선형회귀분석
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개
target = grid_500[["GRADE_폭력"]]

x_data1 = sm.add_constant(x_data, has_constant = "add")


def processSubset(X,y):
    model = sm.OLS(y,X) # Modeling
    regr = model.fit() # model fitting
    AIC = regr.aic # model's AIC
    return {"model" : regr, "AIC" : AIC}
    
processSubset(X = x_data1, y = target)
# Out:
# {'model': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7ff26fb0fb20>,
#  'AIC': 2645.0712390076487}

# %% [markdown]
# ## 전진 선택법

# %%
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개

target = grid_500[["GRADE_폭력"]]

selected_variables = [] ## 선택된 변수들

sl_enter = 0.05
 
sv_per_step = [] ## 각 스텝별로 선택된 변수들
adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
steps = [] ## 스텝
step = 0
while len(x_data) > 0:
    remainder = list(set(x_data) - set(selected_variables))
    pval = pd.Series(index=remainder) ## 변수의 p-value
    ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
    ## 선형 모형을 적합한다.
    for col in remainder: 
        X = x_data[selected_variables+[col]]
        X = sm.add_constant(X)
        model = sm.OLS(target,X).fit()
        pval[col] = model.pvalues[col]
 
    min_pval = pval.min()
    if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
        selected_variables.append(pval.idxmin())
        
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(target,sm.add_constant(x_data[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break

# %%
selected_variables
# Out:
# ['cctv',
#  '유흥시설',
#  '남성인구',
#  '보안등',
#  '35년이상건축물',
#  '개별주택가격',
#  '유소년인구',
#  '성폭력취약인구',
#  '룸살롱',
#  '가로등',
#  '횡단보도',
#  '술집',
#  '교통사고_19',
#  '교통사고_20',
#  '대규모점포',
#  '신호등',
#  '노숙인시설']

# %%
# 다중 선형회귀분석
x_data = grid_500[selected_variables]
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     170.3
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          4.70e-267
# Time:                        14:16:53   Log-Likelihood:                -1296.9
# No. Observations:                 918   AIC:                             2630.
# Df Residuals:                     900   BIC:                             2717.
# Df Model:                          17
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0762      0.045      1.695      0.090      -0.012       0.164
# cctv           0.1117      0.024      4.628      0.000       0.064       0.159
# 유흥시설           0.0004      0.003      0.142      0.887      -0.006       0.006
# 남성인구           0.0038      0.000     11.487      0.000       0.003       0.004
# 보안등           -0.0182      0.002    -10.888      0.000      -0.021      -0.015
# 35년이상건축물       0.0025      0.001      3.829      0.000       0.001       0.004
# 개별주택가격      3.187e-09   4.22e-10      7.553      0.000    2.36e-09    4.02e-09
# 유소년인구         -0.0043      0.001     -7.917      0.000      -0.005      -0.003
# 성폭력취약인구       -0.0108      0.001     -7.380      0.000      -0.014      -0.008
# 룸살롱            0.0585      0.017      3.537      0.000       0.026       0.091
# 가로등            0.0087      0.002      4.280      0.000       0.005       0.013
# 횡단보도           0.0198      0.004      4.587      0.000       0.011       0.028
# 술집             0.0605      0.017      3.505      0.000       0.027       0.094
# 교통사고_19        0.0411      0.011      3.757      0.000       0.020       0.063
# 교통사고_20       -0.0109      0.004     -2.637      0.009      -0.019      -0.003
# 대규모점포         -0.3423      0.144     -2.384      0.017      -0.624      -0.061
# 신호등           -0.0163      0.008     -2.071      0.039      -0.032      -0.001
# 노숙인시설          1.2136      0.589      2.061      0.040       0.058       2.369
# ==============================================================================
# Omnibus:                      327.129   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1549.635
# Skew:                           1.587   Prob(JB):                         0.00
# Kurtosis:                       8.518   Cond. No.                     2.44e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
fig = plt.figure(figsize=(30,30))
fig.set_facecolor('white')
 
font_size = 15
plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=12)
plt.plot(steps,adjusted_r_squared, marker='o')
    
plt.ylabel('Adjusted R Squared',fontsize=font_size)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 후진소거법

# %%
## 후진 소거법
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개

target = grid_500[["GRADE_폭력"]]

selected_variables = x_data.columns.tolist()

sl_remove = 0.05
 
sv_per_step = [] ## 각 스텝별로 선택된 변수들
adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
steps = [] ## 스텝
step = 0
while len(selected_variables) > 0:
    X = sm.add_constant(grid_500[selected_variables])
    p_vals = sm.OLS(target,X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
    max_pval = p_vals.max() ## 최대 p-value
    if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
        remove_variable = p_vals.idxmax()
        selected_variables.remove(remove_variable)
 
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(target,sm.add_constant(x_data[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break

# %%
selected_variables
# Out:
# ['총인구',
#  '남성인구',
#  '유소년인구',
#  '35년이상건축물',
#  '개별주택가격',
#  '가로등',
#  '교통사고_19',
#  '교통사고_20',
#  '노숙인시설',
#  '대규모점포',
#  '룸살롱',
#  '보안등',
#  '술집',
#  '원룸_오피스텔',
#  'cctv',
#  '신호등',
#  '횡단보도',
#  '성폭력취약인구']

# %%
# 다중 선형회귀분석
x_data = grid_500[selected_variables]
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     162.6
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          1.01e-267
# Time:                        14:16:55   Log-Likelihood:                -1292.6
# No. Observations:                 918   AIC:                             2623.
# Df Residuals:                     899   BIC:                             2715.
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0687      0.045      1.524      0.128      -0.020       0.157
# 총인구           -0.0021      0.001     -2.507      0.012      -0.004      -0.000
# 남성인구           0.0079      0.002      4.668      0.000       0.005       0.011
# 유소년인구         -0.0044      0.001     -8.250      0.000      -0.005      -0.003
# 35년이상건축물       0.0021      0.001      3.223      0.001       0.001       0.003
# 개별주택가격      3.188e-09   4.33e-10      7.364      0.000    2.34e-09    4.04e-09
# 가로등            0.0086      0.002      4.358      0.000       0.005       0.012
# 교통사고_19        0.0400      0.011      3.721      0.000       0.019       0.061
# 교통사고_20       -0.0104      0.004     -2.505      0.012      -0.018      -0.002
# 노숙인시설          1.2252      0.586      2.090      0.037       0.075       2.376
# 대규모점포         -0.3312      0.136     -2.439      0.015      -0.598      -0.065
# 룸살롱            0.0559      0.016      3.499      0.000       0.025       0.087
# 보안등           -0.0168      0.002     -9.902      0.000      -0.020      -0.014
# 술집             0.0630      0.009      6.719      0.000       0.045       0.081
# 원룸_오피스텔       -0.0046      0.002     -2.423      0.016      -0.008      -0.001
# cctv           0.1230      0.026      4.808      0.000       0.073       0.173
# 신호등           -0.0156      0.008     -1.985      0.047      -0.031      -0.000
# 횡단보도           0.0198      0.004      4.677      0.000       0.011       0.028
# 성폭력취약인구       -0.0085      0.002     -5.140      0.000      -0.012      -0.005
# ==============================================================================
# Omnibus:                      323.991   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1494.525
# Skew:                           1.580   Prob(JB):                         0.00
# Kurtosis:                       8.394   Cond. No.                     2.44e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
fig = plt.figure(figsize=(30,30))
fig.set_facecolor('white')
 
font_size = 15
plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=12)
plt.plot(steps,adjusted_r_squared, marker='o')
    
plt.ylabel('Adjusted R Squared',fontsize=font_size)
plt.grid(True)
plt.show()

# %%
## 전진 단계별 선택법
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개
variables = x_data.columns.tolist() ## 설명 변수 리스트
 
y = grid_500['GRADE_폭력'] ## 반응 변수
selected_variables = [] ## 선택된 변수들
sl_enter = 0.05
sl_remove = 0.05
 
sv_per_step = [] ## 각 스텝별로 선택된 변수들
adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
steps = [] ## 스텝
step = 0
while len(variables) > 0:
    remainder = list(set(variables) - set(selected_variables))
    pval = pd.Series(index=remainder) ## 변수의 p-value
    ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
    ## 선형 모형을 적합한다.
    for col in remainder: 
        X = grid_500[selected_variables+[col]]
        X = sm.add_constant(X)
        model = sm.OLS(target,X).fit()
        pval[col] = model.pvalues[col]
 
    min_pval = pval.min()
    if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
        selected_variables.append(pval.idxmin())
        ## 선택된 변수들에대해서
        ## 어떤 변수를 제거할지 고른다.
        while len(selected_variables) > 0:
            selected_X = grid_500[selected_variables]
            selected_X = sm.add_constant(selected_X)
            selected_pval = sm.OLS(target,selected_X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
            max_pval = selected_pval.max()
            if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                remove_variable = selected_pval.idxmax()
                selected_variables.remove(remove_variable)
            else:
                break
        
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(target,sm.add_constant(grid_500[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break

# %%
selected_variables
# Out:
# ['cctv',
#  '남성인구',
#  '보안등',
#  '35년이상건축물',
#  '개별주택가격',
#  '유소년인구',
#  '성폭력취약인구',
#  '룸살롱',
#  '가로등',
#  '횡단보도',
#  '술집',
#  '교통사고_19',
#  '교통사고_20',
#  '대규모점포',
#  '신호등',
#  '노숙인시설']

# %%
# 다중 선형회귀분석
x_data = grid_500[selected_variables]
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     181.1
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          3.47e-268
# Time:                        14:17:01   Log-Likelihood:                -1296.9
# No. Observations:                 918   AIC:                             2628.
# Df Residuals:                     901   BIC:                             2710.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0758      0.045      1.691      0.091      -0.012       0.164
# cctv           0.1111      0.024      4.669      0.000       0.064       0.158
# 남성인구           0.0038      0.000     11.610      0.000       0.003       0.004
# 보안등           -0.0181      0.002    -11.013      0.000      -0.021      -0.015
# 35년이상건축물       0.0025      0.001      3.829      0.000       0.001       0.004
# 개별주택가격      3.187e-09   4.22e-10      7.556      0.000    2.36e-09    4.01e-09
# 유소년인구         -0.0043      0.001     -8.002      0.000      -0.005      -0.003
# 성폭력취약인구       -0.0108      0.001     -7.395      0.000      -0.014      -0.008
# 룸살롱            0.0579      0.016      3.615      0.000       0.026       0.089
# 가로등            0.0087      0.002      4.402      0.000       0.005       0.013
# 횡단보도           0.0199      0.004      4.697      0.000       0.012       0.028
# 술집             0.0625      0.009      6.686      0.000       0.044       0.081
# 교통사고_19        0.0414      0.011      3.849      0.000       0.020       0.063
# 교통사고_20       -0.0109      0.004     -2.639      0.008      -0.019      -0.003
# 대규모점포         -0.3354      0.135     -2.482      0.013      -0.601      -0.070
# 신호등           -0.0163      0.008     -2.071      0.039      -0.032      -0.001
# 노숙인시설          1.2174      0.588      2.071      0.039       0.064       2.371
# ==============================================================================
# Omnibus:                      326.851   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1548.390
# Skew:                           1.585   Prob(JB):                         0.00
# Kurtosis:                       8.516   Cond. No.                     2.44e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
fig = plt.figure(figsize=(30,30))
fig.set_facecolor('white')
 
font_size = 15
plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=12)
plt.plot(steps,adjusted_r_squared, marker='o')
    
plt.ylabel('Adjusted R Squared',fontsize=font_size)
plt.grid(True)
plt.show()

# %% [markdown]
# ### standardscale

# %%
scaler = StandardScaler()
grid_500[numerical_feats] = scaler.fit_transform(grid_500[numerical_feats])

# %%
## 전진 단계별 선택법
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개
variables = x_data.columns.tolist() ## 설명 변수 리스트
 
y = grid_500['GRADE_폭력'] ## 반응 변수
selected_variables = [] ## 선택된 변수들
sl_enter = 0.05
sl_remove = 0.05
 
sv_per_step = [] ## 각 스텝별로 선택된 변수들
adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
steps = [] ## 스텝
step = 0
while len(variables) > 0:
    remainder = list(set(variables) - set(selected_variables))
    pval = pd.Series(index=remainder) ## 변수의 p-value
    ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
    ## 선형 모형을 적합한다.
    for col in remainder: 
        X = grid_500[selected_variables+[col]]
        X = sm.add_constant(X)
        model = sm.OLS(target,X).fit()
        pval[col] = model.pvalues[col]
 
    min_pval = pval.min()
    if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
        selected_variables.append(pval.idxmin())
        ## 선택된 변수들에대해서
        ## 어떤 변수를 제거할지 고른다.
        while len(selected_variables) > 0:
            selected_X = grid_500[selected_variables]
            selected_X = sm.add_constant(selected_X)
            selected_pval = sm.OLS(target,selected_X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
            max_pval = selected_pval.max()
            if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                remove_variable = selected_pval.idxmax()
                selected_variables.remove(remove_variable)
            else:
                break
        
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(target,sm.add_constant(grid_500[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break

# %%
selected_variables
# Out:
# ['cctv',
#  '남성인구',
#  '보안등',
#  '35년이상건축물',
#  '개별주택가격',
#  '유소년인구',
#  '성폭력취약인구',
#  '룸살롱',
#  '가로등',
#  '횡단보도',
#  '술집',
#  '교통사고_19',
#  '교통사고_20',
#  '대규모점포',
#  '신호등',
#  '노숙인시설']

# %%
# 다중 선형회귀분석
x_data = grid_500[selected_variables]
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     181.1
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          3.47e-268
# Time:                        14:17:06   Log-Likelihood:                -642.09
# No. Observations:                 918   AIC:                             1318.
# Df Residuals:                     901   BIC:                             1400.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.028e-16      0.016  -6.34e-15      1.000      -0.032       0.032
# cctv           0.1542      0.033      4.669      0.000       0.089       0.219
# 남성인구           1.4063      0.121     11.610      0.000       1.169       1.644
# 보안등           -0.2418      0.022    -11.013      0.000      -0.285      -0.199
# 35년이상건축물       0.0936      0.024      3.829      0.000       0.046       0.142
# 개별주택가격         0.1656      0.022      7.556      0.000       0.123       0.209
# 유소년인구         -0.4521      0.057     -8.002      0.000      -0.563      -0.341
# 성폭력취약인구       -0.7016      0.095     -7.395      0.000      -0.888      -0.515
# 룸살롱            0.0734      0.020      3.615      0.000       0.034       0.113
# 가로등            0.1295      0.029      4.402      0.000       0.072       0.187
# 횡단보도           0.1470      0.031      4.697      0.000       0.086       0.208
# 술집             0.1700      0.025      6.686      0.000       0.120       0.220
# 교통사고_19        0.1193      0.031      3.849      0.000       0.058       0.180
# 교통사고_20       -0.0490      0.019     -2.639      0.008      -0.085      -0.013
# 대규모점포         -0.0449      0.018     -2.482      0.013      -0.080      -0.009
# 신호등           -0.0656      0.032     -2.071      0.039      -0.128      -0.003
# 노숙인시설          0.0340      0.016      2.071      0.039       0.002       0.066
# ==============================================================================
# Omnibus:                      326.851   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1548.390
# Skew:                           1.585   Prob(JB):                         0.00
# Kurtosis:                       8.516   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
## 후진 소거법
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구']] #변수 여러개

target = grid_500[["GRADE_폭력"]]

selected_variables = x_data.columns.tolist()

sl_remove = 0.05
 
sv_per_step = [] ## 각 스텝별로 선택된 변수들
adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
steps = [] ## 스텝
step = 0
while len(selected_variables) > 0:
    X = sm.add_constant(grid_500[selected_variables])
    p_vals = sm.OLS(target,X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
    max_pval = p_vals.max() ## 최대 p-value
    if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
        remove_variable = p_vals.idxmax()
        selected_variables.remove(remove_variable)
 
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(target,sm.add_constant(x_data[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break

# %%
selected_variables
# Out:
# ['총인구',
#  '남성인구',
#  '유소년인구',
#  '35년이상건축물',
#  '개별주택가격',
#  '가로등',
#  '교통사고_19',
#  '교통사고_20',
#  '노숙인시설',
#  '대규모점포',
#  '룸살롱',
#  '보안등',
#  '술집',
#  '원룸_오피스텔',
#  'cctv',
#  '신호등',
#  '횡단보도',
#  '성폭력취약인구']

# %%
# 다중 선형회귀분석
x_data = grid_500[selected_variables]
target = grid_500[["GRADE_폭력"]]

# for b0, 상수항 추가
x_data1 = sm.add_constant(x_data, has_constant = "add")

# OLS 검정
multi_model = sm.OLS(target, x_data1)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               GRADE_폭력   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     162.6
# Date:                Wed, 18 Aug 2021   Prob (F-statistic):          1.01e-267
# Time:                        14:17:06   Log-Likelihood:                -637.84
# No. Observations:                 918   AIC:                             1314.
# Df Residuals:                     899   BIC:                             1405.
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.028e-16      0.016  -6.36e-15      1.000      -0.032       0.032
# 총인구           -1.5718      0.627     -2.507      0.012      -2.802      -0.341
# 남성인구           2.8701      0.615      4.668      0.000       1.663       4.077
# 유소년인구         -0.4674      0.057     -8.250      0.000      -0.579      -0.356
# 35년이상건축물       0.0800      0.025      3.223      0.001       0.031       0.129
# 개별주택가격         0.1656      0.022      7.364      0.000       0.121       0.210
# 가로등            0.1280      0.029      4.358      0.000       0.070       0.186
# 교통사고_19        0.1151      0.031      3.721      0.000       0.054       0.176
# 교통사고_20       -0.0465      0.019     -2.505      0.012      -0.083      -0.010
# 노숙인시설          0.0343      0.016      2.090      0.037       0.002       0.066
# 대규모점포         -0.0443      0.018     -2.439      0.015      -0.080      -0.009
# 룸살롱            0.0709      0.020      3.499      0.000       0.031       0.111
# 보안등           -0.2247      0.023     -9.902      0.000      -0.269      -0.180
# 술집             0.1714      0.026      6.719      0.000       0.121       0.221
# 원룸_오피스텔       -0.0687      0.028     -2.423      0.016      -0.124      -0.013
# cctv           0.1706      0.035      4.808      0.000       0.101       0.240
# 신호등           -0.0629      0.032     -1.985      0.047      -0.125      -0.001
# 횡단보도           0.1459      0.031      4.677      0.000       0.085       0.207
# 성폭력취약인구       -0.5542      0.108     -5.140      0.000      -0.766      -0.343
# ==============================================================================
# Omnibus:                      323.991   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1494.525
# Skew:                           1.580   Prob(JB):                         0.00
# Kurtosis:                       8.394   Cond. No.                         155.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pca = PCA(n_components=5) # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(x_data)
principalDf = pd.DataFrame(data=printcipalComponents, columns = ['principal component1', 'principal component2', 'principal component3', 'principal component4', 'principal component5'])
# 주성분으로 이루어진 데이터 프레임 구성

# %%
principalDf.head()
# Out:
#    principal component1  principal component2  principal component3  \
# 0              1.052377             -0.530157             -0.320274
# 1              4.622388              1.751507             -2.723109
# 2             -1.353748              0.041094             -0.102615
# 3              4.701432              1.318473             -1.619691
# 4             -1.678959              0.040610              0.006880
#
#    principal component4  principal component5
# 0              0.218654              0.207482
# 1              0.419254             -0.449746
# 2              0.155403             -0.050417
# 3             -0.710763              0.430224
# 4              0.197317             -0.180519

# %%
pca.explained_variance_ratio_
# Out:
# array([0.4561501 , 0.10633806, 0.0663735 , 0.05816465, 0.05610025])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.7431265581894393

# %%
selected_variables
# Out:
# ['총인구',
#  '남성인구',
#  '유소년인구',
#  '35년이상건축물',
#  '개별주택가격',
#  '가로등',
#  '교통사고_19',
#  '교통사고_20',
#  '노숙인시설',
#  '대규모점포',
#  '룸살롱',
#  '보안등',
#  '술집',
#  '원룸_오피스텔',
#  'cctv',
#  '신호등',
#  '횡단보도',
#  '성폭력취약인구']

# %%
x_data = grid_500[['총인구',
 '남성인구',
 '유소년인구',
 '35년이상건축물',
 '개별주택가격',
 '가로등',
 '교통사고_19',
 '교통사고_20',
 '노숙인시설',
 '대규모점포',
 '룸살롱',
 '보안등',
 '술집',
 '원룸_오피스텔',
 'cctv',
 '신호등',
 '횡단보도',
 '성폭력취약인구', 'GRADE_폭력']]

# %% [markdown]
# ### Pycaret

# %% [markdown]
# #### 가장 $R^2$가 높았던 변수를 가지고 Pycaret을 이용해 최적의 머신러닝모델 탐색 70% train

# %%
reg = setup(x_data, 
            preprocess = False, # True로 설정되면, 자체적인 Feature Engineering을 추가로 진행해 Predict가 불가능해진다.
            train_size = 0.7,  #0.7트레인
            target = "GRADE_폭력", # 목표 변수는 폭력등급이다.
            silent = True, 
            use_gpu = False, 
            numeric_features=list(x_data.drop(columns = ['GRADE_폭력']).columns), # 모든 변수가 숫자로써의 의미가 있다.
            session_id = 2021,
            fold_shuffle = True
            )
# Out:
# <style  type="text/css" >
# </style><table id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow0_col1" class="data row0 col1" >2021</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow1_col1" class="data row1 col1" >GRADE_폭력</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow2_col1" class="data row2 col1" >(918, 19)</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow4_col1" class="data row4 col1" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow6_col0" class="data row6 col0" >Transformed Train Set</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow6_col1" class="data row6 col1" >(642, 18)</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow7_col0" class="data row7 col0" >Transformed Test Set</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow7_col1" class="data row7 col1" >(276, 18)</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow8_col0" class="data row8 col0" >Shuffle Train-Test</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow8_col1" class="data row8 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow9_col0" class="data row9 col0" >Stratify Train-Test</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow10_col0" class="data row10 col0" >Fold Generator</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow10_col1" class="data row10 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow11_col0" class="data row11 col0" >Fold Number</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow11_col1" class="data row11 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow12_col0" class="data row12 col0" >CPU Jobs</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow12_col1" class="data row12 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow13_col0" class="data row13 col0" >Use GPU</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow13_col1" class="data row13 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow14_col0" class="data row14 col0" >Log Experiment</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow15_col0" class="data row15 col0" >Experiment Name</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow15_col1" class="data row15 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow16_col0" class="data row16 col0" >USI</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow16_col1" class="data row16 col1" >5dab</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow17_col0" class="data row17 col0" >Transform Target</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fablevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow18_col0" class="data row18 col0" >Transform Target Method</td>
#                         <td id="T_88cf1ecc_ffe3_11eb_9a23_acbc32d61fabrow18_col1" class="data row18 col1" >box-cox</td>
#             </tr>
#     </tbody></table>

# %%
top5 = compare_models(n_select = 5, sort = 'RMSE')
# Out:
# <style  type="text/css" >
#     #T_aee2087c_ffe3_11eb_9a23_acbc32d61fab th {
#           text-align: left;
#     }#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow12_col0,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow12_col1,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow12_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow12_col3,#T_aee20 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col2,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col3,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col4,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col5,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col6,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col1{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow0_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow1_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow2_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow3_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow4_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow5_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow6_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow7_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow8_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow9_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow10_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow11_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow12_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow13_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow14_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow15_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow17_col7,#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_aee2087c_ffe3_11eb_9a23_acbc32d61fabrow16_col7{
#             text-align:  left;
#             text-align:  left;

# %% [markdown]
# #### 전체 변수를 이용한 Pycaret 모델 탐색

# %%
x_data = grid_500[['총인구', '남성인구', '여성인구', '고등여성인구', '20대여성인구', '유소년인구',
       '고령인구', '30년이상35년미만건축물', '35년이상건축물', '개별주택가격', '공시지가', '가로등',
       '공영주차장', '공중화장실', '교육시설', '교통사고_19', '교통사고_20', '노숙인시설', '대규모점포',
       '대부업현황', '룸살롱', '버스정류장', '보안등', '상가', '숙박업소', '술집', '어린이보호', '어린이집',
       '오락시설', '원룸_오피스텔', '유흥시설', '음식점', '자율방범대', '파출소', 'cctv', '신호등', '횡단보도',
       '성폭력취약인구','GRADE_폭력']]

# %%
reg = setup(x_data, 
            preprocess = False, # True로 설정되면, 자체적인 Feature Engineering을 추가로 진행해 Predict가 불가능해진다.
            train_size = 0.7,  
            target = "GRADE_폭력", 
            silent = True, 
            use_gpu = False, 
            numeric_features=list(x_data.drop(columns = ['GRADE_폭력']).columns), # 모든 변수가 숫자로써의 의미가 있다.
            session_id = 2021,
            fold_shuffle = True
            )
# Out:
# <style  type="text/css" >
# </style><table id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow0_col1" class="data row0 col1" >2021</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow1_col1" class="data row1 col1" >GRADE_폭력</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow2_col1" class="data row2 col1" >(918, 39)</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow4_col1" class="data row4 col1" >38</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow6_col0" class="data row6 col0" >Transformed Train Set</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow6_col1" class="data row6 col1" >(642, 38)</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow7_col0" class="data row7 col0" >Transformed Test Set</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow7_col1" class="data row7 col1" >(276, 38)</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow8_col0" class="data row8 col0" >Shuffle Train-Test</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow8_col1" class="data row8 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow9_col0" class="data row9 col0" >Stratify Train-Test</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow10_col0" class="data row10 col0" >Fold Generator</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow10_col1" class="data row10 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow11_col0" class="data row11 col0" >Fold Number</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow11_col1" class="data row11 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow12_col0" class="data row12 col0" >CPU Jobs</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow12_col1" class="data row12 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow13_col0" class="data row13 col0" >Use GPU</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow13_col1" class="data row13 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow14_col0" class="data row14 col0" >Log Experiment</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow15_col0" class="data row15 col0" >Experiment Name</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow15_col1" class="data row15 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow16_col0" class="data row16 col0" >USI</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow16_col1" class="data row16 col1" >781f</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow17_col0" class="data row17 col0" >Transform Target</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fablevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow18_col0" class="data row18 col0" >Transform Target Method</td>
#                         <td id="T_af7fe506_ffe3_11eb_9a23_acbc32d61fabrow18_col1" class="data row18 col1" >box-cox</td>
#             </tr>
#     </tbody></table>

# %%
top5 = compare_models(n_select = 5, sort = 'RMSE')
# Out:
# <style  type="text/css" >
#     #T_d2febc64_ffe3_11eb_9a23_acbc32d61fab th {
#           text-align: left;
#     }#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col6,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow12_col0,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow12_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow12_col2,#T_d2febc ...
#             text-align:  left;
#             text-align:  left;
#         }#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col1,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col2,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col3,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col4,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col5,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow0_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow1_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow2_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow3_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow4_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow5_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow6_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow9_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow10_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow11_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow12_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow13_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow14_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow15_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow16_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow17_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow7_col7,#T_d2febc64_ffe3_11eb_9a23_acbc32d61fabrow8_col7{
#             text-align:  left;
#             text-align:  left;

# %%
gbr = create_model('gbr', cross_validation = False)
rf = create_model('rf', cross_validation = False)
cat = create_model('catboost', cross_validation = False)
# Out:
#       MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  0.2867  0.2464  0.4964  0.7504  0.2176  0.8759

# %%
# 하이퍼파라미터 튜닝
tuned_gbr = tune_model(gbr, optimize = 'RMSE', n_iter = 10)
tuned_rf = tune_model(rf, optimize = 'RMSE', n_iter = 10)
tuned_cat = tune_model(cat, optimize = 'RMSE', n_iter = 10)
# Out:
# <style  type="text/css" >
# #T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow10_col0,#T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow10_col1,#T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow10_col2,#T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow10_col3,#T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow10_col4,#T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow10_col5{
#             background:  yellow;
#         }</style><table id="T_bd729662_ffe4_11eb_9a23_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow0_col0" class="data row0 col0" >0.2665</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow0_col1" class="data row0 col1" >0.2913</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow0_col2" class="data row0 col2" >0.5397</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow0_col3" class="data row0 col3" >0.6105</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow0_col4" class="data row0 col4" >0.2367</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow0_col5" class="data row0 col5" >0.7454</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow1_col0" class="data row1 col0" >0.2381</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow1_col1" class="data row1 col1" >0.1831</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow1_col2" class="data row1 col2" >0.4279</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow1_col3" class="data row1 col3" >0.7407</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow1_col4" class="data row1 col4" >0.2067</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow1_col5" class="data row1 col5" >0.6318</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow2_col0" class="data row2 col0" >0.3277</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow2_col1" class="data row2 col1" >0.2688</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow2_col2" class="data row2 col2" >0.5185</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow2_col3" class="data row2 col3" >0.7254</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow2_col4" class="data row2 col4" >0.2404</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow2_col5" class="data row2 col5" >1.1638</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow3_col0" class="data row3 col0" >0.2289</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow3_col1" class="data row3 col1" >0.1687</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow3_col2" class="data row3 col2" >0.4108</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow3_col3" class="data row3 col3" >0.8264</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow3_col4" class="data row3 col4" >0.2020</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow3_col5" class="data row3 col5" >0.8221</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow4_col0" class="data row4 col0" >0.3597</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow4_col1" class="data row4 col1" >0.3334</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow4_col2" class="data row4 col2" >0.5774</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow4_col3" class="data row4 col3" >0.7514</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow4_col4" class="data row4 col4" >0.2095</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow4_col5" class="data row4 col5" >0.8622</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow5_col0" class="data row5 col0" >0.2665</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow5_col1" class="data row5 col1" >0.1922</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow5_col2" class="data row5 col2" >0.4384</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow5_col3" class="data row5 col3" >0.8645</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow5_col4" class="data row5 col4" >0.1850</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow5_col5" class="data row5 col5" >0.6754</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow6_col0" class="data row6 col0" >0.1805</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow6_col1" class="data row6 col1" >0.1090</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow6_col2" class="data row6 col2" >0.3301</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow6_col3" class="data row6 col3" >0.6973</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow6_col4" class="data row6 col4" >0.1418</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow6_col5" class="data row6 col5" >0.5702</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow7_col0" class="data row7 col0" >0.3223</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow7_col1" class="data row7 col1" >0.3461</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow7_col2" class="data row7 col2" >0.5883</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow7_col3" class="data row7 col3" >0.6953</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow7_col4" class="data row7 col4" >0.2502</td>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow7_col5" class="data row7 col5" >0.5825</td>
#             </tr>
#             <tr>
#                         <th id="T_bd729662_ffe4_11eb_9a23_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_bd729662_ffe4_11eb_9a23_acbc32d61fabrow8_col0" class="data row8 col0" >0.3032</td>
#                         <td id

# %%
# 모델 블렌딩(Blend)

blender_specific = blend_models(estimator_list = [tuned_gbr,tuned_rf,tuned_cat], optimize = 'RMSE')
# Out:
# <style  type="text/css" >
# #T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow10_col0,#T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow10_col1,#T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow10_col2,#T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow10_col3,#T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow10_col4,#T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow10_col5{
#             background:  yellow;
#         }</style><table id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fab" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow0_col0" class="data row0 col0" >0.2571</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow0_col1" class="data row0 col1" >0.2471</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow0_col2" class="data row0 col2" >0.4970</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow0_col3" class="data row0 col3" >0.6696</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow0_col4" class="data row0 col4" >0.2202</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow0_col5" class="data row0 col5" >0.8931</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow1_col0" class="data row1 col0" >0.2425</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow1_col1" class="data row1 col1" >0.2090</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow1_col2" class="data row1 col2" >0.4572</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow1_col3" class="data row1 col3" >0.7040</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow1_col4" class="data row1 col4" >0.1958</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow1_col5" class="data row1 col5" >0.6435</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow2_col0" class="data row2 col0" >0.3202</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow2_col1" class="data row2 col1" >0.2692</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow2_col2" class="data row2 col2" >0.5189</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow2_col3" class="data row2 col3" >0.7250</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow2_col4" class="data row2 col4" >0.2291</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow2_col5" class="data row2 col5" >1.1448</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow3_col0" class="data row3 col0" >0.2252</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow3_col1" class="data row3 col1" >0.1513</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow3_col2" class="data row3 col2" >0.3889</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow3_col3" class="data row3 col3" >0.8444</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow3_col4" class="data row3 col4" >0.1908</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow3_col5" class="data row3 col5" >0.8533</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow4_col0" class="data row4 col0" >0.3384</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow4_col1" class="data row4 col1" >0.3119</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow4_col2" class="data row4 col2" >0.5585</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow4_col3" class="data row4 col3" >0.7674</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow4_col4" class="data row4 col4" >0.2168</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow4_col5" class="data row4 col5" >0.8359</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow5_col0" class="data row5 col0" >0.2706</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow5_col1" class="data row5 col1" >0.2227</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow5_col2" class="data row5 col2" >0.4719</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow5_col3" class="data row5 col3" >0.8430</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow5_col4" class="data row5 col4" >0.1866</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow5_col5" class="data row5 col5" >0.6472</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow6_col0" class="data row6 col0" >0.1823</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow6_col1" class="data row6 col1" >0.1061</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow6_col2" class="data row6 col2" >0.3258</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow6_col3" class="data row6 col3" >0.7051</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow6_col4" class="data row6 col4" >0.1524</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow6_col5" class="data row6 col5" >0.6447</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow7_col0" class="data row7 col0" >0.2895</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow7_col1" class="data row7 col1" >0.2849</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow7_col2" class="data row7 col2" >0.5338</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow7_col3" class="data row7 col3" >0.7492</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow7_col4" class="data row7 col4" >0.2496</td>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow7_col5" class="data row7 col5" >0.5833</td>
#             </tr>
#             <tr>
#                         <th id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fablevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d6d79666_ffe4_11eb_9a23_acbc32d61fabrow8_col0" class="data row8 col0" >0.3034</td>
#                         <td id

# %%
# 모델 시각화(plot)_plot = 'residuals'

plot_model(blender_specific)

# %%
# 모델 시각화(plot)_plot = 'error'

plot_model(blender_specific, plot='error')

# %%
# 모델 시각화(plot)_plot = 'learning'

plot_model(blender_specific, plot='learning')
# Out:
# IntProgress(value=0, description='Processing: ', max=5)

# %% [markdown]
# #### 80%의 트레인셋으로 모델 적합

# %%
reg = setup(x_data, 
            preprocess = False, # True로 설정되면, 자체적인 Feature Engineering을 추가로 진행해 Predict가 불가능해진다.
            train_size = 0.8,  
            target = "GRADE_폭력", 
            silent = True, 
            use_gpu = False, 
            numeric_features=list(x_data.drop(columns = ['GRADE_폭력']).columns), # 모든 변수가 숫자로써의 의미가 있다.
            session_id = 2021,
            fold_shuffle = True
            )

# %%
top5 = compare_models(n_select = 5, sort = 'RMSE')
